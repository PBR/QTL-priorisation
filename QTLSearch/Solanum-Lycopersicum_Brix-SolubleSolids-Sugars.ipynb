# %% [markdown]
# Implementation algorithm
#
# Alex Warwick Vesztrocy, Christophe Dessimoz, Henning Redestig, Prioritising candidate genes causing QTL using hierarchical orthologous groups, *Bioinformatics*, Volume 34, Issue 17, 01 September 2018, Pages i612–i619, https://doi.org/10.1093/bioinformatics/bty615

# %%
import qtlsearch
import pandas as pd
from IPython.display import Image,SVG
search = qtlsearch.SEARCH(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl:8890/sparql", 
    "http://sparql.omabrowser.org/sparql",
    "https://sparql.uniprot.org/sparql")

# %% [markdown]
# ## Brix, Soluble Solids, Sugars
#
# GO-terms: `GO:0006094` `GO:0046370` `GO:0046369` `GO:0005985` `GO:0015770`
#
# QTL from: Chromosome `9`, around `3474710`
#
# Candidate: `Lin5` (`Solyc09g010080`)

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
d=100000
intervalT = search.make_interval(
    "http://localhost:8890/genome/Solanum_lycopersicum/chromosome/9", 
    3474710-d, 
    3474710+d)

#genes for interval
genesT = search.interval_genes(intervalT)

# %% [markdown]
# Compute the list of GO annotations

# %%
qtls = [genesT.index]
go_annotations = pd.concat([search.get_child_annotations("GO:0006094"), search.get_child_annotations("GO:0046370"), search.get_child_annotations("GO:0046369"), search.get_child_annotations("GO:0005985"), search.get_child_annotations("GO:0015770")])
print(go_annotations)
# Out:
#                                                                                        label
# go_annotation
# http://purl.obolibrary.org/obo/GO_0006094                                    gluconeogenesis
# http://purl.obolibrary.org/obo/GO_0046370                      fructose biosynthetic process
# http://purl.obolibrary.org/obo/GO_1901358        beta-D-galactofuranose biosynthetic process
# http://purl.obolibrary.org/obo/GO_0046369                     galactose biosynthetic process
# http://purl.obolibrary.org/obo/GO_0005985                          sucrose metabolic process
# http://purl.obolibrary.org/obo/GO_0005986                       sucrose biosynthetic process
# http://purl.obolibrary.org/obo/GO_0061705  sucrose catabolic process to fructose-6-phosph...
# http://purl.obolibrary.org/obo/GO_0005987                          sucrose catabolic process
# http://purl.obolibrary.org/obo/GO_0061704                    glycolytic process from sucrose
# http://purl.obolibrary.org/obo/GO_0061706  glycolytic process from sucrose through glucos...
# http://purl.obolibrary.org/obo/GO_0019574       sucrose catabolic process via 3'-ketosucrose
# http://purl.obolibrary.org/obo/GO_0036008  sucrose catabolic process to fructose-6-phosph...
# http://purl.obolibrary.org/obo/GO_0009915                             phloem sucrose loading
# http://purl.obolibrary.org/obo/GO_0106082              sucrose import across plasma membrane
# http://purl.obolibrary.org/obo/GO_1904982                    sucrose transmembrane transport
# http://purl.obolibrary.org/obo/GO_0015770                                  sucrose transport

# %% [markdown]
# Get data and do computations

# %%
result = qtlsearch.QTLSEARCH(search, qtls, go_annotations, True)

# %% [markdown]
# Create report

# %%
report_list = result.report()
for report in report_list:    
    display(report)
# Out:
#                       alias uniprot_id  \
# gene_id
# Solyc09g010090.2       LIN7     Q8L4N2
# Solyc09g010080.2       lin5     Q9LD97
# Solyc09g010020.2                K4CR31
# Solyc09g010040.1  101248415     K4CR33
# Solyc09g010000.2  101249481     K4CR29
# Solyc09g009900.2                K4CR19
# Solyc09g009910.2  101252320     K4CR20
# Solyc09g009920.1  101252019     K4CR21
# Solyc09g009930.1  101251713     K4CR22
# Solyc09g009940.2  101251215     K4CR23
# Solyc09g009950.2                K4CR24
# Solyc09g009960.2                K4CR25
# Solyc09g009970.2  101250330     K4CR26
# Solyc09g009980.1  101250042     K4CR27
# Solyc09g009990.2  101249753     K4CR28
# Solyc09g010010.1                K4CR30
# Solyc09g010030.1  101248704     K4CR32
# Solyc09g010050.1  101248129     K4CR34
# Solyc09g010060.2  101247848     K4CR35
# Solyc09g010070.1  101258097     K4CR36
# Solyc09g010100.2  101256436     K4D3B5
# Solyc09g010110.2  101247247     K4CR40
# Solyc09g010120.2  101246952     K4CR41
# Solyc09g010130.2                K4CR42
# Solyc09g010140.1  101246370     K4CR43
# Solyc09g010150.2                K4CR44
# Solyc09g010160.1  101257801     K4CR45
# Solyc09g010170.2                K4CR46
# Solyc09g010180.2        SPY     Q8RVB2
#
#                                                         description  \
# gene_id
# Solyc09g010090.2                                Cell-wall invertase
# Solyc09g010080.2     Beta-fructofuranosidase, insoluble isoenzyme 1
# Solyc09g010020.2  1-aminocyclopropane-1-carboxylate oxidase-like...
# Solyc09g010040.1  1-aminocyclopropane-1-carboxylate oxidase-like...
# Solyc09g010000.2  1-aminocyclopropane-1-carboxylate oxidase-like...
# Solyc09g009900.2                     Pollen-specific protein - like
# Solyc09g009910.2  Lipid A ABC transporter permease/ATP-binding p...
# Solyc09g009920.1                               F-box family protein
# Solyc09g009930.1                                    Unknown Protein
# Solyc09g009940.2                Signal recognition particle protein
# Solyc09g009950.2        Pentatricopeptide repeat-containing protein
# Solyc09g009960.2  4&apos-phosphopantetheinyl transferase family ...
# Solyc09g009970.2                    Rho GTPase activating protein 2
# Solyc09g009980.1                    Auxin-induced SAUR-like protein
# Solyc09g009990.2               Transposon protein Mutator sub-class
# Solyc09g010010.1          1-aminocyclopropane-1-carboxylate oxidase
# Solyc09g010030.1                        50S ribosomal protein L12-2
# Solyc09g010050.1                                          Cullin 1B
# Solyc09g010060.2                                            Kinesin
# Solyc09g010070.1        Pentatricopeptide repeat-containing protein
# Solyc09g010100.2                          30S ribosomal protein S11
# Solyc09g010110.2                        Chaperone protein dnaJ-like
# Solyc09g010120.2                                    Unknown Protein
# Solyc09g010130.2                                    Sorting nexin 1
# Solyc09g010140.1  Arabidopsis thaliana genomic DNA chromosome 5 ...
# Solyc09g010150.2  Short-chain dehydrogenase/reductase family pro...
# Solyc09g010160.1                       NAC domain protein IPR003441
# Solyc09g010170.2     Vacuolar protein sorting 55 containing protein
# Solyc09g010180.2                      TPR repeat-containing protein
#
#                  chromosome         location     score
# gene_id
# Solyc09g010090.2          9  3480545-3484159  0.202943
# Solyc09g010080.2          9  3475480-3479343  0.172502
# Solyc09g010020.2          9  3447416-3449839  0.043606
# Solyc09g010040.1          9  3454295-3455561  0.043606
# Solyc09g010000.2          9  3444303-3445806  0.037065
# Solyc09g009900.2          9  3382755-3386531  0.034483
# Solyc09g009910.2          9  3386287-3395367  0.034483
# Solyc09g009920.1          9  3397388-3398827  0.034483
# Solyc09g009930.1          9  3400106-3400900  0.034483
# Solyc09g009940.2          9  3401811-3408955  0.034483
# Solyc09g009950.2          9  3409650-3411653  0.034483
# Solyc09g009960.2          9  3412363-3416452  0.034483
# Solyc09g009970.2          9  3418544-3423024  0.034483
# Solyc09g009980.1          9  3436952-3437398  0.034483
# Solyc09g009990.2          9  3438477-3443240  0.034483
# Solyc09g010010.1          9  3446639-3447244  0.034483
# Solyc09g010030.1          9  3451744-3452328  0.034483
# Solyc09g010050.1          9  3455757-3457964  0.034483
# Solyc09g010060.2          9  3460580-3468455  0.034483
# Solyc09g010070.1          9  3468712-3470580  0.034483
# Solyc09g010100.2          9  3488735-3491402  0.034483
# Solyc09g010110.2          9  3492711-3497716  0.034483
# Solyc09g010120.2          9  3499761-3502328  0.034483
# Solyc09g010130.2          9  3503323-3510006  0.034483
# Solyc09g010140.1          9  3516951-3517673  0.034483
# Solyc09g010150.2          9  3521393-3529854  0.034483
# Solyc09g010160.1          9  3540687-3545497  0.034483
# Solyc09g010170.2          9  3548667-3552545  0.034483
# Solyc09g010180.2          9  3556738-3572844  0.000000
