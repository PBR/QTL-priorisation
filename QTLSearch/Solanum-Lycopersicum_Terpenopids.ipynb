# %% [markdown]
# Implementation algorithm
#
# Alex Warwick Vesztrocy, Christophe Dessimoz, Henning Redestig, Prioritising candidate genes causing QTL using hierarchical orthologous groups, *Bioinformatics*, Volume 34, Issue 17, 01 September 2018, Pages i612–i619, https://doi.org/10.1093/bioinformatics/bty615

# %%
import qtlsearch
import pandas as pd
from IPython.display import Image,SVG
search = qtlsearch.SEARCH(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl:8890/sparql", 
    "http://sparql.omabrowser.org/sparql",
    "https://sparql.uniprot.org/sparql")

# %% [markdown]
# ## Terpenoids
#
# GO-terms: `GO:0003677`, `GO:0045893`
#
# QTL from: `Chromosome 1` : `86142248` - `86467672`
#
# Candidate: `Terpense synthase`

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
intervalT = search.make_interval(
    "http://localhost:8890/genome/Solanum_lycopersicum/chromosome/1", 
    86142248,
    86467672)


#genes for interval
genesT = search.interval_genes(intervalT)

# %% [markdown]
# Compute the list of GO annotations

# %%
qtls = [genesT.index]
go_annotations = pd.concat([
    search.get_child_annotations("GO:0003677"),
    search.get_child_annotations("GO:0045893")
])
print(go_annotations)
# Out:
#                                                                                        label
# go_annotation
# http://purl.obolibrary.org/obo/GO_0061821                           telomeric D-loop binding
# http://purl.obolibrary.org/obo/GO_0003677                                        DNA binding
# http://purl.obolibrary.org/obo/GO_0010736                     serum response element binding
# http://purl.obolibrary.org/obo/GO_1990955                 G-rich single-stranded DNA binding
# http://purl.obolibrary.org/obo/GO_0000978  RNA polymerase II proximal promoter sequence-s...
# http://purl.obolibrary.org/obo/GO_0032140                   single adenine insertion binding
# http://purl.obolibrary.org/obo/GO_1990471                   piRNA uni-strand cluster binding
# http://purl.obolibrary.org/obo/GO_0035538              carbohydrate response element binding
# http://purl.obolibrary.org/obo/GO_0001006  RNA polymerase III type 3 promoter sequence-sp...
# http://purl.obolibrary.org/obo/GO_0001030     RNA polymerase III type 1 promoter DNA binding
# http://purl.obolibrary.org/obo/GO_0001162  RNA polymerase II intronic transcription regul...
# http://purl.obolibrary.org/obo/GO_0032142                   single guanine insertion binding
# http://purl.obolibrary.org/obo/GO_0000979  RNA polymerase II core promoter sequence-speci...
# http://purl.obolibrary.org/obo/GO_0035484                    adenine/adenine mispair binding
# http://purl.obolibrary.org/obo/GO_0000976  transcription regulatory region sequence-speci...
# http://purl.obolibrary.org/obo/GO_0003695                            random coil DNA binding
# http://purl.obolibrary.org/obo/GO_0001003  RNA polymerase III type 2 promoter sequence-sp...
# http://purl.obolibrary.org/obo/GO_0032356                               oxidized DNA binding
# http://purl.obolibrary.org/obo/GO_0032138          single base insertion or deletion binding
# http://purl.obolibrary.org/obo/GO_0032422    purine-rich negative regulatory element binding
# http://purl.obolibrary.org/obo/GO_0001160         transcription termination site DNA binding
# http://purl.obolibrary.org/obo/GO_0001019  plastid RNA polymerase regulatory region DNA b...
# http://purl.obolibrary.org/obo/GO_1990470                              piRNA cluster binding
# http://purl.obolibrary.org/obo/GO_0000992  polymerase III regulatory region sequence-spec...
# http://purl.obolibrary.org/obo/GO_0061730                C-rich strand telomeric DNA binding
# http://purl.obolibrary.org/obo/GO_0061777                                 DNA clamp activity
# http://purl.obolibrary.org/obo/GO_0110035  rDNA spacer replication fork barrier binding, ...
# http://purl.obolibrary.org/obo/GO_0035485                    adenine/guanine mispair binding
# http://purl.obolibrary.org/obo/GO_0070644                 vitamin D response element binding
# http://purl.obolibrary.org/obo/GO_0000497                              base pairing with DNA
# ...                                                                                      ...
# http://purl.obolibrary.org/obo/GO_0051039  positive regulation of transcription involved ...
# http://purl.obolibrary.org/obo/GO_1900423  positive regulation of mating type switching b...
# http://purl.obolibrary.org/obo/GO_0000435  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_1905382  positive regulation of snRNA transcription by ...
# http://purl.obolibrary.org/obo/GO_0061404  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_0061424  positive regulation of peroxisome organization...
# http://purl.obolibrary.org/obo/GO_0061188  negative regulation of chromatin silencing at ...
# http://purl.obolibrary.org/obo/GO_0007329  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_0035948  positive regulation of gluconeogenesis by posi...
# http://purl.obolibrary.org/obo/GO_0045991      carbon catabolite activation of transcription
# http://purl.obolibrary.org/obo/GO_0061422  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_1901838  positive regulation of transcription of nucleo...
# http://purl.obolibrary.org/obo/GO_0036086  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_0090310  negative regulation of methylation-dependent c...
# http://purl.obolibrary.org/obo/GO_0007072  positive regulation of transcription involved ...
# http://purl.obolibrary.org/obo/GO_1901522  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_0010735  positive regulation of transcription via serum...
# http://purl.obolibrary.org/obo/GO_1904501  positive regulation of chromatin-mediated main...
# http://purl.obolibrary.org/obo/GO_0000436  carbon catabolite activation of transcription ...
# http://purl.obolibrary.org/obo/GO_1904595  positive regulation of termination of RNA poly...
# http://purl.obolibrary.org/obo/GO_0090203  transcriptional activation by promoter-termina...
# http://purl.obolibrary.org/obo/GO_1904080  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_0000432  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_1900422  positive regulation of cellular alcohol catabo...
# http://purl.obolibrary.org/obo/GO_0007073  positive regulation of transcription involved ...
# http://purl.obolibrary.org/obo/GO_0045895  positive regulation of mating-type specific tr...
# http://purl.obolibrary.org/obo/GO_0001197  positive regulation of mating-type specific tr...
# http://purl.obolibrary.org/obo/GO_1900461  positive regulation of pseudohyphal growth by ...
# http://purl.obolibrary.org/obo/GO_0007075  positive regulation of transcription involved ...
# http://purl.obolibrary.org/obo/GO_0061421  positive regulation of transcription by oleic ...
#
# [294 rows x 1 columns]

# %% [markdown]
# Get data and do computations

# %%
result = qtlsearch.QTLSEARCH(search, qtls,go_annotations)
# Out:
# === GET DATA ===
# Search for Solyc01g094700.2
# - root is http://omabrowser.org/ontology/oma#GROUP_179453
# - tree of groups fetched: 39
# - proteins within tree fetched: 57
# - uniprot proteins within tree fetched: 47
#   * check proteins (1-50): 0 with required annotation
# - checked 47 uniprot proteins: 0 with required annotation
# - checked 57 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094710.1
# - no groups found
# Search for Solyc01g094720.2
# - root is http://omabrowser.org/ontology/oma#GROUP_425805
# - tree of groups fetched: 10000
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9986
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 0 with required annotation
#   * check proteins (151-200): 0 with required annotation
#   * check proteins (201-250): 0 with required annotation
#   * check proteins (251-300): 0 with required annotation
#   * check proteins (301-350): 0 with required annotation
#   * check proteins (351-400): 0 with required annotation
#   * check proteins (401-450): 0 with required annotation
#   * check proteins (451-500): 0 with required annotation
#   * check proteins (501-550): 0 with required annotation
#   * check proteins (551-600): 0 with required annotation
#   * check proteins (601-650): 0 with required annotation
#   * check proteins (651-700): 0 with required annotation
#   * check proteins (701-750): 0 with required annotation
#   * check proteins (751-800): 0 with required annotation
#   * check proteins (801-850): 0 with required annotation
#   * check proteins (851-900): 0 with required annotation
#   * check proteins (901-950): 0 with required annotation
#   * check proteins (951-1000): 0 with required annotation
#   * check proteins (1001-1050): 0 with required annotation
#   * check proteins (1051-1100): 0 with required annotation
#   * check proteins (1101-1150): 0 with required annotation
#   * check proteins (1151-1200): 0 with required annotation
#   * check proteins (1201-1250): 0 with required annotation
#   * check proteins (1251-1300): 0 with required annotation
#   * check proteins (1301-1350): 0 with required annotation
#   * check proteins (1351-1400): 0 with required annotation
#   * check proteins (1401-1450): 0 with required annotation
#   * check proteins (1451-1500): 0 with required annotation
#   * check proteins (1501-1550): 0 with required annotation
#   * check proteins (1551-1600): 0 with required annotation
#   * check proteins (1601-1650): 0 with required annotation
#   * check proteins (1651-1700): 0 with required annotation
#   * check proteins (1701-1750): 0 with required annotation
#   * check proteins (1751-1800): 0 with required annotation
#   * check proteins (1801-1850): 0 with required annotation
#   * check proteins (1851-1900): 0 with required annotation
#   * check proteins (1901-1950): 0 with required annotation
#   * check proteins (1951-2000): 0 with required annotation
#   * check proteins (2001-2050): 0 with required annotation
#   * check proteins (2051-2100): 0 with required annotation
#   * check proteins (2101-2150): 0 with required annotation
#   * check proteins (2151-2200): 0 with required annotation
#   * check proteins (2201-2250): 0 with required annotation
#   * check proteins (2251-2300): 0 with required annotation
#   * check proteins (2301-2350): 0 with required annotation
#   * check proteins (2351-2400): 0 with required annotation
#   * check proteins (2401-2450): 0 with required annotation
#   * check proteins (2451-2500): 0 with required annotation
#   * check proteins (2501-2550): 0 with required annotation
#   * check proteins (2551-2600): 0 with required annotation
#   * check proteins (2601-2650): 0 with required annotation
#   * check proteins (2651-2700): 0 with required annotation
#   * check proteins (2701-2750): 0 with required annotation
#   * check proteins (2751-2800): 0 with required annotation
#   * check proteins (2801-2850): 0 with required annotation
#   * check proteins (2851-2900): 0 with required annotation
#   * check proteins (2901-2950): 0 with required annotation
#   * check proteins (2951-3000): 0 with required annotation
#   * check proteins (3001-3050): 0 with required annotation
#   * check proteins (3051-3100): 0 with required annotation
#   * check proteins (3101-3150): 0 with required annotation
#   * check proteins (3151-3200): 0 with required annotation
#   * check proteins (3201-3250): 0 with required annotation
#   * check proteins (3251-3300): 0 with required annotation
#   * check proteins (3301-3350): 0 with required annotation
#   * check proteins (3351-3400): 0 with required annotation
#   * check proteins (3401-3450): 0 with required annotation
#   * check proteins (3451-3500): 0 with required annotation
#   * check proteins (3501-3550): 0 with required annotation
#   * check proteins (3551-3600): 0 with required annotation
#   * check proteins (3601-3650): 0 with required annotation
#   * check proteins (3651-3700): 0 with required annotation
#   * check proteins (3701-3750): 0 with required annotation
#   * check proteins (3751-3800): 0 with required annotation
#   * check proteins (3801-3850): 0 with required annotation
#   * check proteins (3851-3900): 0 with required annotation
#   * check proteins (3901-3950): 0 with required annotation
#   * check proteins (3951-4000): 0 with required annotation
#   * check proteins (4001-4050): 0 with required annotation
#   * check proteins (4051-4100): 0 with required annotation
#   * check proteins (4101-4150): 0 with required annotation
#   * check proteins (4151-4200): 0 with required annotation
#   * check proteins (4201-4250): 0 with required annotation
#   * check proteins (4251-4300): 0 with required annotation
#   * check proteins (4301-4350): 0 with required annotation
#   * check proteins (4351-4400): 0 with required annotation
#   * check proteins (4401-4450): 0 with required annotation
#   * check proteins (4451-4500): 0 with required annotation
#   * check proteins (4501-4550): 0 with required annotation
#   * check proteins (4551-4600): 0 with required annotation
#   * check proteins (4601-4650): 0 with required annotation
#   * check proteins (4651-4700): 0 with required annotation
#   * check proteins (4701-4750): 0 with required annotation
#   * check proteins (4751-4800): 0 with required annotation
#   * check proteins (4801-4850): 0 with required annotation
#   * check proteins (4851-4900): 0 with required annotation
#   * check proteins (4901-4950): 0 with required annotation
#   * check proteins (4951-5000): 0 with required annotation
#   * check proteins (5001-5050): 0 with required annotation
#   * check proteins (5051-5100): 0 with required annotation
#   * check proteins (5101-5150): 0 with required annotation
#   * check proteins (5151-5200): 0 with required annotation
#   * check proteins (5201-5250): 0 with required annotation
#   * check proteins (5251-5300): 0 with required annotation
#   * check proteins (5301-5350): 0 with required annotation
#   * check proteins (5351-5400): 0 with required annotation
#   * check proteins (5401-5450): 0 with required annotation
#   * check proteins (5451-5500): 0 with required annotation
#   * check proteins (5501-5550): 0 with required annotation
#   * check proteins (5551-5600): 0 with required annotation
#   * check proteins (5601-5650): 0 with required annotation
#   * check proteins (5651-5700): 0 with required annotation
#   * check proteins (5701-5750): 0 with required annotation
#   * check proteins (5751-5800): 0 with required annotation
#   * check proteins (5801-5850): 0 with required annotation
#   * check proteins (5851-5900): 0 with required annotation
#   * check proteins (5901-5950): 0 with required annotation
#   * check proteins (5951-6000): 0 with required annotation
#   * check proteins (6001-6050): 0 with required annotation
#   * check proteins (6051-6100): 0 with required annotation
#   * check proteins (6101-6150): 0 with required annotation
#   * check proteins (6151-6200): 0 with required annotation
#   * check proteins (6201-6250): 0 with required annotation
#   * check proteins (6251-6300): 0 with required annotation
#   * check proteins (6301-6350): 0 with required annotation
#   * check proteins (6351-6400): 0 with required annotation
#   * check proteins (6401-6450): 0 with required annotation
#   * check proteins (6451-6500): 0 with required annotation
#   * check proteins (6501-6550): 0 with required annotation
#   * check proteins (6551-6600): 0 with required annotation
#   * check proteins (6601-6650): 0 with required annotation
#   * check proteins (6651-6700): 0 with required annotation
#   * check proteins (6701-6750): 0 with required annotation
#   * check proteins (6751-6800): 0 with required annotation
#   * check proteins (6801-6850): 0 with required annotation
#   * check proteins (6851-6900): 0 with required annotation
#   * check proteins (6901-6950): 0 with required annotation
#   * check proteins (6951-7000): 0 with required annotation
#   * check proteins (7001-7050): 0 with required annotation
#   * check proteins (7051-7100): 0 with required annotation
#   * check proteins (7101-7150): 0 with required annotation
#   * check proteins (7151-7200): 0 with required annotation
#   * check proteins (7201-7250): 0 with required annotation
#   * check proteins (7251-7300): 0 with required annotation
#   * check proteins (7301-7350): 0 with required annotation
#   * check proteins (7351-7400): 0 with required annotation
#   * check proteins (7401-7450): 0 with required annotation
#   * check proteins (7451-7500): 0 with required annotation
#   * check proteins (7501-7550): 0 with required annotation
#   * check proteins (7551-7600): 0 with required annotation
#   * check proteins (7601-7650): 0 with required annotation
#   * check proteins (7651-7700): 0 with required annotation
#   * check proteins (7701-7750): 0 with required annotation
#   * check proteins (7751-7800): 0 with required annotation
#   * check proteins (7801-7850): 0 with required annotation
#   * check proteins (7851-7900): 0 with required annotation
#   * check proteins (7901-7950): 0 with required annotation
#   * check proteins (7951-8000): 0 with required annotation
#   * check proteins (8001-8050): 0 with required annotation
#   * check proteins (8051-8100): 0 with required annotation
#   * check proteins (8101-8150): 0 with required annotation
#   * check proteins (8151-8200): 0 with required annotation
#   * check proteins (8201-8250): 0 with required annotation
#   * check proteins (8251-8300): 0 with required annotation
#   * check proteins (8301-8350): 0 with required annotation
#   * check proteins (8351-8400): 0 with required annotation
#   * check proteins (8401-8450): 0 with required annotation
#   * check proteins (8451-8500): 0 with required annotation
#   * check proteins (8501-8550): 0 with required annotation
#   * check proteins (8551-8600): 0 with required annotation
#   * check proteins (8601-8650): 0 with required annotation
#   * check proteins (8651-8700): 0 with required annotation
#   * check proteins (8701-8750): 0 with required annotation
#   * check proteins (8751-8800): 0 with required annotation
#   * check proteins (8801-8850): 0 with required annotation
#   * check proteins (8851-8900): 0 with required annotation
#   * check proteins (8901-8950): 0 with required annotation
#   * check proteins (8951-9000): 0 with required annotation
#   * check proteins (9001-9050): 0 with required annotation
#   * check proteins (9051-9100): 0 with required annotation
#   * check proteins (9101-9150): 0 with required annotation
#   * check proteins (9151-9200): 0 with required annotation
#   * check proteins (9201-9250): 0 with required annotation
#   * check proteins (9251-9300): 0 with required annotation
#   * check proteins (9301-9350): 0 with required annotation
#   * check proteins (9351-9400): 0 with required annotation
#   * check proteins (9401-9450): 0 with required annotation
#   * check proteins (9451-9500): 0 with required annotation
#   * check proteins (9501-9550): 0 with required annotation
#   * check proteins (9551-9600): 0 with required annotation
#   * check proteins (9601-9650): 0 with required annotation
#   * check proteins (9651-9700): 0 with required annotation
#   * check proteins (9701-9750): 0 with required annotation
#   * check proteins (9751-9800): 0 with required annotation
#   * check proteins (9801-9850): 0 with required annotation
#   * check proteins (9851-9900): 0 with required annotation
#   * check proteins (9901-9950): 0 with required annotation
#   * check proteins (9951-10000): 0 with required annotation
# - checked 9986 uniprot proteins: 0 with required annotation
# - checked 10001 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094740.1
# - no groups found
# Search for Solyc01g094750.2
# - root is http://omabrowser.org/ontology/oma#GROUP_416199
# - tree of groups fetched: 9383
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9992
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 0 with required annotation
#   * check proteins (151-200): 0 with required annotation
#   * check proteins (201-250): 0 with required annotation
#   * check proteins (251-300): 0 with required annotation
#   * check proteins (301-350): 0 with required annotation
#   * check proteins (351-400): 0 with required annotation
#   * check proteins (401-450): 0 with required annotation
#   * check proteins (451-500): 0 with required annotation
#   * check proteins (501-550): 0 with required annotation
#   * check proteins (551-600): 0 with required annotation
#   * check proteins (601-650): 0 with required annotation
#   * check proteins (651-700): 0 with required annotation
#   * check proteins (701-750): 0 with required annotation
#   * check proteins (751-800): 0 with required annotation
#   * check proteins (801-850): 0 with required annotation
#   * check proteins (851-900): 0 with required annotation
#   * check proteins (901-950): 0 with required annotation
#   * check proteins (951-1000): 0 with required annotation
#   * check proteins (1001-1050): 0 with required annotation
#   * check proteins (1051-1100): 0 with required annotation
#   * check proteins (1101-1150): 0 with required annotation
#   * check proteins (1151-1200): 0 with required annotation
#   * check proteins (1201-1250): 0 with required annotation
#   * check proteins (1251-1300): 0 with required annotation
#   * check proteins (1301-1350): 0 with required annotation
#   * check proteins (1351-1400): 0 with required annotation
#   * check proteins (1401-1450): 0 with required annotation
#   * check proteins (1451-1500): 0 with required annotation
#   * check proteins (1501-1550): 0 with required annotation
#   * check proteins (1551-1600): 0 with required annotation
#   * check proteins (1601-1650): 0 with required annotation
#   * check proteins (1651-1700): 0 with required annotation
#   * check proteins (1701-1750): 0 with required annotation
#   * check proteins (1751-1800): 0 with required annotation
#   * check proteins (1801-1850): 0 with required annotation
#   * check proteins (1851-1900): 0 with required annotation
#   * check proteins (1901-1950): 0 with required annotation
#   * check proteins (1951-2000): 0 with required annotation
#   * check proteins (2001-2050): 0 with required annotation
#   * check proteins (2051-2100): 0 with required annotation
#   * check proteins (2101-2150): 0 with required annotation
#   * check proteins (2151-2200): 0 with required annotation
#   * check proteins (2201-2250): 0 with required annotation
#   * check proteins (2251-2300): 0 with required annotation
#   * check proteins (2301-2350): 0 with required annotation
#   * check proteins (2351-2400): 0 with required annotation
#   * check proteins (2401-2450): 0 with required annotation
#   * check proteins (2451-2500): 0 with required annotation
#   * check proteins (2501-2550): 0 with required annotation
#   * check proteins (2551-2600): 0 with required annotation
#   * check proteins (2601-2650): 0 with required annotation
#   * check proteins (2651-2700): 0 with required annotation
#   * check proteins (2701-2750): 0 with required annotation
#   * check proteins (2751-2800): 0 with required annotation
#   * check proteins (2801-2850): 0 with required annotation
#   * check proteins (2851-2900): 0 with required annotation
#   * check proteins (2901-2950): 0 with required annotation
#   * check proteins (2951-3000): 0 with required annotation
#   * check proteins (3001-3050): 0 with required annotation
#   * check proteins (3051-3100): 0 with required annotation
#   * check proteins (3101-3150): 0 with required annotation
#   * check proteins (3151-3200): 0 with required annotation
#   * check proteins (3201-3250): 0 with required annotation
#   * check proteins (3251-3300): 0 with required annotation
#   * check proteins (3301-3350): 0 with required annotation
#   * check proteins (3351-3400): 0 with required annotation
#   * check proteins (3401-3450): 0 with required annotation
#   * check proteins (3451-3500): 0 with required annotation
#   * check proteins (3501-3550): 0 with required annotation
#   * check proteins (3551-3600): 0 with required annotation
#   * check proteins (3601-3650): 0 with required annotation
#   * check proteins (3651-3700): 0 with required annotation
#   * check proteins (3701-3750): 0 with required annotation
#   * check proteins (3751-3800): 0 with required annotation
#   * check proteins (3801-3850): 0 with required annotation
#   * check proteins (3851-3900): 0 with required annotation
#   * check proteins (3901-3950): 1 with required annotation
#   * check proteins (3951-4000): 0 with required annotation
#   * check proteins (4001-4050): 0 with required annotation
#   * check proteins (4051-4100): 0 with required annotation
#   * check proteins (4101-4150): 0 with required annotation
#   * check proteins (4151-4200): 0 with required annotation
#   * check proteins (4201-4250): 0 with required annotation
#   * check proteins (4251-4300): 0 with required annotation
#   * check proteins (4301-4350): 0 with required annotation
#   * check proteins (4351-4400): 0 with required annotation
#   * check proteins (4401-4450): 0 with required annotation
#   * check proteins (4451-4500): 0 with required annotation
#   * check proteins (4501-4550): 0 with required annotation
#   * check proteins (4551-4600): 0 with required annotation
#   * check proteins (4601-4650): 0 with required annotation
#   * check proteins (4651-4700): 0 with required annotation
#   * check proteins (4701-4750): 0 with required annotation
#   * check proteins (4751-4800): 0 with required annotation
#   * check proteins (4801-4850): 0 with required annotation
#   * check proteins (4851-4900): 0 with required annotation
#   * check proteins (4901-4950): 0 with required annotation
#   * check proteins (4951-5000): 0 with required annotation
#   * check proteins (5001-5050): 0 with required annotation
#   * check proteins (5051-5100): 0 with required annotation
#   * check proteins (5101-5150): 0 with required annotation
#   * check proteins (5151-5200): 0 with required annotation
#   * check proteins (5201-5250): 0 with required annotation
#   * check proteins (5251-5300): 0 with required annotation
#   * check proteins (5301-5350): 0 with required annotation
#   * check proteins (5351-5400): 0 with required annotation
#   * check proteins (5401-5450): 0 with required annotation
#   * check proteins (5451-5500): 0 with required annotation
#   * check proteins (5501-5550): 0 with required annotation
#   * check proteins (5551-5600): 0 with required annotation
#   * check proteins (5601-5650): 0 with required annotation
#   * check proteins (5651-5700): 0 with required annotation
#   * check proteins (5701-5750): 0 with required annotation
#   * check proteins (5751-5800): 0 with required annotation
#   * check proteins (5801-5850): 0 with required annotation
#   * check proteins (5851-5900): 0 with required annotation
#   * check proteins (5901-5950): 0 with required annotation
#   * check proteins (5951-6000): 0 with required annotation
#   * check proteins (6001-6050): 0 with required annotation
#   * check proteins (6051-6100): 0 with required annotation
#   * check proteins (6101-6150): 0 with required annotation
#   * check proteins (6151-6200): 0 with required annotation
#   * check proteins (6201-6250): 0 with required annotation
#   * check proteins (6251-6300): 0 with required annotation
#   * check proteins (6301-6350): 0 with required annotation
#   * check proteins (6351-6400): 0 with required annotation
#   * check proteins (6401-6450): 0 with required annotation
#   * check proteins (6451-6500): 0 with required annotation
#   * check proteins (6501-6550): 0 with required annotation
#   * check proteins (6551-6600): 0 with required annotation
#   * check proteins (6601-6650): 0 with required annotation
#   * check proteins (6651-6700): 0 with required annotation
#   * check proteins (6701-6750): 0 with required annotation
#   * check proteins (6751-6800): 0 with required annotation
#   * check proteins (6801-6850): 0 with required annotation
#   * check proteins (6851-6900): 0 with required annotation
#   * check proteins (6901-6950): 0 with required annotation
#   * check proteins (6951-7000): 0 with required annotation
#   * check proteins (7001-7050): 0 with required annotation
#   * check proteins (7051-7100): 0 with required annotation
#   * check proteins (7101-7150): 0 with required annotation
#   * check proteins (7151-7200): 0 with required annotation
#   * check proteins (7201-7250): 0 with required annotation
#   * check proteins (7251-7300): 0 with required annotation
#   * check proteins (7301-7350): 0 with required annotation
#   * check proteins (7351-7400): 0 with required annotation
#   * check proteins (7401-7450): 0 with required annotation
#   * check proteins (7451-7500): 0 with required annotation
#   * check proteins (7501-7550): 0 with required annotation
#   * check proteins (7551-7600): 0 with required annotation
#   * check proteins (7601-7650): 0 with required annotation
#   * check proteins (7651-7700): 0 with required annotation
#   * check proteins (7701-7750): 0 with required annotation
#   * check proteins (7751-7800): 0 with required annotation
#   * check proteins (7801-7850): 0 with required annotation
#   * check proteins (7851-7900): 0 with required annotation
#   * check proteins (7901-7950): 0 with required annotation
#   * check proteins (7951-8000): 0 with required annotation
#   * check proteins (8001-8050): 0 with required annotation
#   * check proteins (8051-8100): 0 with required annotation
#   * check proteins (8101-8150): 0 with required annotation
#   * check proteins (8151-8200): 0 with required annotation
#   * check proteins (8201-8250): 0 with required annotation
#   * check proteins (8251-8300): 0 with required annotation
#   * check proteins (8301-8350): 0 with required annotation
#   * check proteins (8351-8400): 0 with required annotation
#   * check proteins (8401-8450): 0 with required annotation
#   * check proteins (8451-8500): 0 with required annotation
#   * check proteins (8501-8550): 0 with required annotation
#   * check proteins (8551-8600): 0 with required annotation
#   * check proteins (8601-8650): 0 with required annotation
#   * check proteins (8651-8700): 0 with required annotation
#   * check proteins (8701-8750): 0 with required annotation
#   * check proteins (8751-8800): 0 with required annotation
#   * check proteins (8801-8850): 0 with required annotation
#   * check proteins (8851-8900): 0 with required annotation
#   * check proteins (8901-8950): 0 with required annotation
#   * check proteins (8951-9000): 0 with required annotation
#   * check proteins (9001-9050): 0 with required annotation
#   * check proteins (9051-9100): 0 with required annotation
#   * check proteins (9101-9150): 0 with required annotation
#   * check proteins (9151-9200): 0 with required annotation
#   * check proteins (9201-9250): 0 with required annotation
#   * check proteins (9251-9300): 0 with required annotation
#   * check proteins (9301-9350): 0 with required annotation
#   * check proteins (9351-9400): 0 with required annotation
#   * check proteins (9401-9450): 0 with required annotation
#   * check proteins (9451-9500): 0 with required annotation
#   * check proteins (9501-9550): 0 with required annotation
#   * check proteins (9551-9600): 0 with required annotation
#   * check proteins (9601-9650): 0 with required annotation
#   * check proteins (9651-9700): 0 with required annotation
#   * check proteins (9701-9750): 0 with required annotation
#   * check proteins (9751-9800): 0 with required annotation
#   * check proteins (9801-9850): 0 with required annotation
#   * check proteins (9851-9900): 0 with required annotation
#   * check proteins (9901-9950): 0 with required annotation
#   * check proteins (9951-10000): 0 with required annotation
# - checked 9992 uniprot proteins: 1 with required annotation
#   -> for 1 of these 9992 items, reviewed is True
# - checked 10001 proteins: 1 linked to uniprot with required annotation
#   -> for 1 of these 10001 items reviewed is marked as True
# Search for Solyc01g094760.2
# - root is http://omabrowser.org/ontology/oma#GROUP_422298
# - tree of groups fetched: 48
# - proteins within tree fetched: 69
# - uniprot proteins within tree fetched: 51
#   * check proteins (1-50): 8 with required annotation
#     -> Pooideae, Oryza sativa, Arabidopsis, Andropogoneae
#   * check proteins (51-69): 0 with required annotation
# - checked 51 uniprot proteins: 8 with required annotation
#   -> for 8 of these 51 items, reviewed is True
# - checked 69 proteins: 8 linked to uniprot with required annotation
#   -> for 8 of these 69 items reviewed is marked as True
# Search for Solyc01g094770.2
# - root is http://omabrowser.org/ontology/oma#GROUP_174425
# - tree of groups fetched: 48
# - proteins within tree fetched: 67
# - uniprot proteins within tree fetched: 55
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-67): 0 with required annotation
# - checked 55 uniprot proteins: 0 with required annotation
# - checked 67 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094780.2
# - root is http://omabrowser.org/ontology/oma#GROUP_184737
# - tree of groups fetched: 45
# - proteins within tree fetched: 62
# - uniprot proteins within tree fetched: 53
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-62): 0 with required annotation
# - checked 53 uniprot proteins: 0 with required annotation
# - checked 62 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094790.2
# - root is http://omabrowser.org/ontology/oma#GROUP_418761
# - tree of groups fetched: 789
# - proteins within tree fetched: 1295
# - uniprot proteins within tree fetched: 919
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 0 with required annotation
#   * check proteins (151-200): 0 with required annotation
#   * check proteins (201-250): 0 with required annotation
#   * check proteins (251-300): 0 with required annotation
#   * check proteins (301-350): 0 with required annotation
#   * check proteins (351-400): 0 with required annotation
#   * check proteins (401-450): 0 with required annotation
#   * check proteins (451-500): 0 with required annotation
#   * check proteins (501-550): 0 with required annotation
#   * check proteins (551-600): 0 with required annotation
#   * check proteins (601-650): 0 with required annotation
#   * check proteins (651-700): 0 with required annotation
#   * check proteins (701-750): 0 with required annotation
#   * check proteins (751-800): 0 with required annotation
#   * check proteins (801-850): 0 with required annotation
#   * check proteins (851-900): 0 with required annotation
#   * check proteins (901-950): 0 with required annotation
# - checked 919 uniprot proteins: 0 with required annotation
# - checked 1295 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094800.2
# - root is http://omabrowser.org/ontology/oma#GROUP_174075
# - tree of groups fetched: 44
# - proteins within tree fetched: 68
# - uniprot proteins within tree fetched: 47
#   * check proteins (1-50): 12 with required annotation
#     -> Oryza sativa, Magnoliophyta, Oryza, Triticum, Arabidopsis
# - checked 47 uniprot proteins: 12 with required annotation
#   -> for 12 of these 47 items, reviewed is True
# - checked 68 proteins: 12 linked to uniprot with required annotation
#   -> for 12 of these 68 items reviewed is marked as True
# Search for Solyc01g094810.2
# - root is http://omabrowser.org/ontology/oma#GROUP_421042
# - tree of groups fetched: 4112
# - proteins within tree fetched: 6746
# - uniprot proteins within tree fetched: 4866
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 3 with required annotation
#     -> Schizosaccharomyces, Phytophthora
#   * check proteins (151-200): 0 with required annotation
#   * check proteins (201-250): 0 with required annotation
#   * check proteins (251-300): 1 with required annotation
#     -> Schizosaccharomyces
#   * check proteins (301-350): 3 with required annotation
#     -> Debaryomycetaceae, Aspergillus, Saccharomycetaceae
#   * check proteins (351-400): 0 with required annotation
#   * check proteins (401-450): 0 with required annotation
#   * check proteins (451-500): 0 with required annotation
#   * check proteins (501-550): 0 with required annotation
#   * check proteins (551-600): 0 with required annotation
#   * check proteins (601-650): 0 with required annotation
#   * check proteins (651-700): 0 with required annotation
#   * check proteins (701-750): 0 with required annotation
#   * check proteins (751-800): 2 with required annotation
#     -> Debaryomycetaceae, Cryptococcus
#   * check proteins (801-850): 0 with required annotation
#   * check proteins (851-900): 0 with required annotation
#   * check proteins (901-950): 0 with required annotation
#   * check proteins (951-1000): 0 with required annotation
#   * check proteins (1001-1050): 0 with required annotation
#   * check proteins (1051-1100): 0 with required annotation
#   * check proteins (1101-1150): 1 with required annotation
#     -> Schizosaccharomyces
#   * check proteins (1151-1200): 2 with required annotation
#     -> Debaryomycetaceae, Puccinia graminis
#   * check proteins (1201-1250): 0 with required annotation
#   * check proteins (1251-1300): 0 with required annotation
#   * check proteins (1301-1350): 0 with required annotation
#   * check proteins (1351-1400): 2 with required annotation
#     -> Saccharomycetaceae
#   * check proteins (1401-1450): 0 with required annotation
#   * check proteins (1451-1500): 0 with required annotation
#   * check proteins (1501-1550): 0 with required annotation
#   * check proteins (1551-1600): 2 with required annotation
#     -> Phaffomycetaceae, Ustilago
#   * check proteins (1601-1650): 0 with required annotation
#   * check proteins (1651-1700): 0 with required annotation
#   * check proteins (1701-1750): 2 with required annotation
#     -> Schizosaccharomyces
#   * check proteins (1751-1800): 3 with required annotation
#     -> Agaricomycetes incertae sedis, Saccharomycetaceae, Debaryomycetaceae
#   * check proteins (1801-1850): 1 with required annotation
#     -> Polyporaceae
#   * check proteins (1851-1900): 0 with required annotation
#   * check proteins (1901-1950): 2 with required annotation
#     -> Schizosaccharomyces, Pezizomycotina
#   * check proteins (1951-2000): 3 with required annotation
#     -> Saccharomycetaceae, Polyporales, Dothideomycetes
#   * check proteins (2001-2050): 0 with required annotation
#   * check proteins (2051-2100): 0 with required annotation
#   * check proteins (2101-2150): 1 with required annotation
#     -> Schizosaccharomyces
#   * check proteins (2151-2200): 0 with required annotation
#   * check proteins (2201-2250): 1 with required annotation
#     -> Neurospora
#   * check proteins (2251-2300): 0 with required annotation
#   * check proteins (2301-2350): 0 with required annotation
#   * check proteins (2351-2400): 0 with required annotation
#   * check proteins (2401-2450): 0 with required annotation
#   * check proteins (2451-2500): 0 with required annotation
#   * check proteins (2501-2550): 2 with required annotation
#     -> Fusarium, Mycosphaerellaceae
#   * check proteins (2551-2600): 0 with required annotation
#   * check proteins (2601-2650): 0 with required annotation
#   * check proteins (2651-2700): 0 with required annotation
#   * check proteins (2701-2750): 0 with required annotation
#   * check proteins (2751-2800): 0 with required annotation
#   * check proteins (2801-2850): 0 with required annotation
#   * check proteins (2851-2900): 0 with required annotation
#   * check proteins (2901-2950): 0 with required annotation
#   * check proteins (2951-3000): 0 with required annotation
#   * check proteins (3001-3050): 2 with required annotation
#     -> Phaeosphaeria nodorum, Sclerotiniaceae
#   * check proteins (3051-3100): 0 with required annotation
#   * check proteins (3101-3150): 0 with required annotation
#   * check proteins (3151-3200): 0 with required annotation
#   * check proteins (3201-3250): 2 with required annotation
#     -> Candida/Lodderomyces clade, Neurospora
#   * check proteins (3251-3300): 1 with required annotation
#     -> Polyporales
#   * check proteins (3301-3350): 1 with required annotation
#     -> Trichoderma
#   * check proteins (3351-3400): 0 with required annotation
#   * check proteins (3401-3450): 0 with required annotation
#   * check proteins (3451-3500): 0 with required annotation
#   * check proteins (3501-3550): 0 with required annotation
#   * check proteins (3551-3600): 0 with required annotation
#   * check proteins (3601-3650): 0 with required annotation
#   * check proteins (3651-3700): 0 with required annotation
#   * check proteins (3701-3750): 0 with required annotation
#   * check proteins (3751-3800): 0 with required annotation
#   * check proteins (3801-3850): 2 with required annotation
#     -> Aspergillus, Verticillium dahliae
#   * check proteins (3851-3900): 0 with required annotation
#   * check proteins (3901-3950): 0 with required annotation
#   * check proteins (3951-4000): 0 with required annotation
#   * check proteins (4001-4050): 0 with required annotation
#   * check proteins (4051-4100): 1 with required annotation
#     -> Magnaporthe
#   * check proteins (4101-4150): 0 with required annotation
#   * check proteins (4151-4200): 2 with required annotation
#     -> Pleosporaceae
#   * check proteins (4201-4250): 0 with required annotation
#   * check proteins (4251-4300): 1 with required annotation
#     -> Aspergillus
#   * check proteins (4301-4350): 3 with required annotation
#     -> Aspergillus, Onygenales incertae sedis, Pleosporineae
#   * check proteins (4351-4400): 1 with required annotation
#     -> Trichoderma
#   * check proteins (4401-4450): 0 with required annotation
#   * check proteins (4451-4500): 0 with required annotation
#   * check proteins (4501-4550): 1 with required annotation
#     -> Hypocreales
#   * check proteins (4551-4600): 0 with required annotation
#   * check proteins (4601-4650): 0 with required annotation
#   * check proteins (4651-4700): 0 with required annotation
#   * check proteins (4701-4750): 3 with required annotation
#     -> Sordariomycetes, Otophysi, Emericella nidulans
#   * check proteins (4751-4800): 0 with required annotation
#   * check proteins (4801-4850): 0 with required annotation
#   * check proteins (4851-4900): 0 with required annotation
# - checked 4866 uniprot proteins: 51 with required annotation
#   -> for 51 of these 4866 items, reviewed is True
# - checked 6746 proteins: 51 linked to uniprot with required annotation
#   -> for 51 of these 6746 items reviewed is marked as True
# Search for Solyc01g094820.2
# - root is http://omabrowser.org/ontology/oma#GROUP_162795
# - tree of groups fetched: 28
# - proteins within tree fetched: 41
# - uniprot proteins within tree fetched: 26
#   * check proteins (1-41): 22 with required annotation
#     -> Malvaceae, 50 kb inversion clade, Brassica, Gossypium, fabids, Phaseoleae, Hologalegina, Solanum
# - checked 26 uniprot proteins: 22 with required annotation
#   -> for 22 of these 26 items, reviewed is True
# - checked 41 proteins: 22 linked to uniprot with required annotation
#   -> for 22 of these 41 items reviewed is marked as True
# Search for Solyc01g094830.2
# - root is http://omabrowser.org/ontology/oma#GROUP_180323
# - tree of groups fetched: 59
# - proteins within tree fetched: 88
# - uniprot proteins within tree fetched: 68
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-88): 0 with required annotation
# - checked 68 uniprot proteins: 0 with required annotation
# - checked 88 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094840.2
# - root is http://omabrowser.org/ontology/oma#GROUP_183292
# - tree of groups fetched: 48
# - proteins within tree fetched: 67
# - uniprot proteins within tree fetched: 50
#   * check proteins (1-50): 0 with required annotation
# - checked 50 uniprot proteins: 0 with required annotation
# - checked 67 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094850.1
# - root is http://omabrowser.org/ontology/oma#GROUP_177213
# - tree of groups fetched: 32
# - proteins within tree fetched: 44
# - uniprot proteins within tree fetched: 31
#   * check proteins (1-44): 0 with required annotation
# - checked 31 uniprot proteins: 0 with required annotation
# - checked 44 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094860.2
# - root is http://omabrowser.org/ontology/oma#GROUP_183058
# - tree of groups fetched: 43
# - proteins within tree fetched: 64
# - uniprot proteins within tree fetched: 47
#   * check proteins (1-50): 0 with required annotation
# - checked 47 uniprot proteins: 0 with required annotation
# - checked 64 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094870.1
# - root is http://omabrowser.org/ontology/oma#GROUP_184516
# - tree of groups fetched: 93
# - proteins within tree fetched: 131
# - uniprot proteins within tree fetched: 114
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-131): 0 with required annotation
# - checked 114 uniprot proteins: 0 with required annotation
# - checked 131 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094880.2
# - root is http://omabrowser.org/ontology/oma#GROUP_433013
# - tree of groups fetched: 45
# - proteins within tree fetched: 61
# - uniprot proteins within tree fetched: 51
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-61): 0 with required annotation
# - checked 51 uniprot proteins: 0 with required annotation
# - checked 61 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094890.2
# - root is http://omabrowser.org/ontology/oma#GROUP_183693
# - tree of groups fetched: 132
# - proteins within tree fetched: 202
# - uniprot proteins within tree fetched: 149
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 0 with required annotation
# - checked 149 uniprot proteins: 0 with required annotation
# - checked 202 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094900.1
# - root is http://omabrowser.org/ontology/oma#GROUP_126994
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-2): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094910.2
# - root is http://omabrowser.org/ontology/oma#GROUP_183693
# - tree already created
# Search for Solyc01g094920.2
# - root is http://omabrowser.org/ontology/oma#GROUP_168660
# - tree of groups fetched: 37
# - proteins within tree fetched: 53
# - uniprot proteins within tree fetched: 42
#   * check proteins (1-50): 0 with required annotation
# - checked 42 uniprot proteins: 0 with required annotation
# - checked 53 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094930.2
# - root is http://omabrowser.org/ontology/oma#GROUP_626939
# - tree of groups fetched: 422
# - proteins within tree fetched: 792
# - uniprot proteins within tree fetched: 639
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 3 with required annotation
#     -> Metatheria, Caniformia, Bovidae
#   * check proteins (101-150): 1 with required annotation
#     -> Murinae
#   * check proteins (151-200): 2 with required annotation
#     -> Cercopithecinae, Homininae
#   * check proteins (201-250): 5 with required annotation
#     -> Caniformia, Metatheria, Primates, Hystricomorpha
#   * check proteins (251-300): 3 with required annotation
#     -> Murinae, Caniformia, Cetartiodactyla
#   * check proteins (301-350): 0 with required annotation
#   * check proteins (351-400): 1 with required annotation
#     -> Chiroptera
#   * check proteins (401-450): 1 with required annotation
#     -> Laurasiatheria
#   * check proteins (451-500): 0 with required annotation
#   * check proteins (501-550): 2 with required annotation
#     -> Bovidae, Lagomorpha
#   * check proteins (551-600): 2 with required annotation
#     -> Afrotheria, Cetartiodactyla
#   * check proteins (601-650): 0 with required annotation
# - checked 639 uniprot proteins: 20 with required annotation
#   -> for 20 of these 639 items, reviewed is True
# - checked 792 proteins: 20 linked to uniprot with required annotation
#   -> for 20 of these 792 items reviewed is marked as True
# Search for Solyc01g094940.2
# - root is http://omabrowser.org/ontology/oma#GROUP_161157
# - tree of groups fetched: 9
# - proteins within tree fetched: 18
# - uniprot proteins within tree fetched: 11
#   * check proteins (1-18): 0 with required annotation
# - checked 11 uniprot proteins: 0 with required annotation
# - checked 18 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094950.2
# - root is http://omabrowser.org/ontology/oma#GROUP_178701
# - tree of groups fetched: 73
# - proteins within tree fetched: 101
# - uniprot proteins within tree fetched: 78
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
# - checked 78 uniprot proteins: 0 with required annotation
# - checked 101 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094960.2
# - root is http://omabrowser.org/ontology/oma#GROUP_434470
# - tree of groups fetched: 10000
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9993
#   * check proteins (1-50): 6 with required annotation
#   * check proteins (51-100): 3 with required annotation
#   * check proteins (101-150): 4 with required annotation
#   * check proteins (151-200): 1 with required annotation
#   * check proteins (201-250): 6 with required annotation
#   * check proteins (251-300): 1 with required annotation
#   * check proteins (301-350): 2 with required annotation
#   * check proteins (351-400): 2 with required annotation
#   * check proteins (401-450): 0 with required annotation
#   * check proteins (451-500): 1 with required annotation
#   * check proteins (501-550): 0 with required annotation
#   * check proteins (551-600): 2 with required annotation
#   * check proteins (601-650): 0 with required annotation
#   * check proteins (651-700): 0 with required annotation
#   * check proteins (701-750): 1 with required annotation
#   * check proteins (751-800): 0 with required annotation
#   * check proteins (801-850): 2 with required annotation
#   * check proteins (851-900): 0 with required annotation
#   * check proteins (901-950): 5 with required annotation
#   * check proteins (951-1000): 1 with required annotation
#   * check proteins (1001-1050): 1 with required annotation
#   * check proteins (1051-1100): 1 with required annotation
#   * check proteins (1101-1150): 2 with required annotation
#   * check proteins (1151-1200): 1 with required annotation
#   * check proteins (1201-1250): 2 with required annotation
#   * check proteins (1251-1300): 2 with required annotation
#   * check proteins (1301-1350): 0 with required annotation
#   * check proteins (1351-1400): 0 with required annotation
#   * check proteins (1401-1450): 1 with required annotation
#   * check proteins (1451-1500): 0 with required annotation
#   * check proteins (1501-1550): 1 with required annotation
#   * check proteins (1551-1600): 0 with required annotation
#   * check proteins (1601-1650): 0 with required annotation
#   * check proteins (1651-1700): 1 with required annotation
#   * check proteins (1701-1750): 2 with required annotation
#   * check proteins (1751-1800): 0 with required annotation
#   * check proteins (1801-1850): 0 with required annotation
#   * check proteins (1851-1900): 1 with required annotation
#   * check proteins (1901-1950): 1 with required annotation
#   * check proteins (1951-2000): 1 with required annotation
#   * check proteins (2001-2050): 0 with required annotation
#   * check proteins (2051-2100): 0 with required annotation
#   * check proteins (2101-2150): 2 with required annotation
#   * check proteins (2151-2200): 5 with required annotation
#   * check proteins (2201-2250): 4 with required annotation
#   * check proteins (2251-2300): 6 with required annotation
#   * check proteins (2301-2350): 5 with required annotation
#   * check proteins (2351-2400): 3 with required annotation
#   * check proteins (2401-2450): 4 with required annotation
#   * check proteins (2451-2500): 1 with required annotation
#   * check proteins (2501-2550): 3 with required annotation
#   * check proteins (2551-2600): 1 with required annotation
#   * check proteins (2601-2650): 1 with required annotation
#   * check proteins (2651-2700): 2 with required annotation
#   * check proteins (2701-2750): 3 with required annotation
#   * check proteins (2751-2800): 3 with required annotation
#   * check proteins (2801-2850): 3 with required annotation
#   * check proteins (2851-2900): 0 with required annotation
#   * check proteins (2901-2950): 3 with required annotation
#   * check proteins (2951-3000): 4 with required annotation
#   * check proteins (3001-3050): 0 with required annotation
#   * check proteins (3051-3100): 3 with required annotation
#   * check proteins (3101-3150): 1 with required annotation
#   * check proteins (3151-3200): 0 with required annotation
#   * check proteins (3201-3250): 1 with required annotation
#   * check proteins (3251-3300): 3 with required annotation
#   * check proteins (3301-3350): 1 with required annotation
#   * check proteins (3351-3400): 1 with required annotation
#   * check proteins (3401-3450): 1 with required annotation
#   * check proteins (3451-3500): 0 with required annotation
#   * check proteins (3501-3550): 2 with required annotation
#   * check proteins (3551-3600): 0 with required annotation
#   * check proteins (3601-3650): 0 with required annotation
#   * check proteins (3651-3700): 0 with required annotation
#   * check proteins (3701-3750): 1 with required annotation
#   * check proteins (3751-3800): 2 with required annotation
#   * check proteins (3801-3850): 1 with required annotation
#   * check proteins (3851-3900): 2 with required annotation
#   * check proteins (3901-3950): 1 with required annotation
#   * check proteins (3951-4000): 1 with required annotation
#   * check proteins (4001-4050): 0 with required annotation
#   * check proteins (4051-4100): 0 with required annotation
#   * check proteins (4101-4150): 0 with required annotation
#   * check proteins (4151-4200): 1 with required annotation
#   * check proteins (4201-4250): 0 with required annotation
#   * check proteins (4251-4300): 1 with required annotation
#   * check proteins (4301-4350): 3 with required annotation
#   * check proteins (4351-4400): 1 with required annotation
#   * check proteins (4401-4450): 5 with required annotation
#   * check proteins (4451-4500): 7 with required annotation
#   * check proteins (4501-4550): 2 with required annotation
#   * check proteins (4551-4600): 2 with required annotation
#   * check proteins (4601-4650): 3 with required annotation
#   * check proteins (4651-4700): 3 with required annotation
#   * check proteins (4701-4750): 3 with required annotation
#   * check proteins (4751-4800): 1 with required annotation
#   * check proteins (4801-4850): 1 with required annotation
#   * check proteins (4851-4900): 3 with required annotation
#   * check proteins (4901-4950): 0 with required annotation
# ...
#   * check proteins (5251-5300): 1 with required annotation
#   * check proteins (5301-5350): 2 with required annotation
#   * check proteins (5351-5400): 2 with required annotation
#   * check proteins (5401-5450): 3 with required annotation
#   * check proteins (5451-5500): 0 with required annotation
#   * check proteins (5501-5550): 4 with required annotation
#   * check proteins (5551-5600): 3 with required annotation
#   * check proteins (5601-5650): 0 with required annotation
#   * check proteins (5651-5700): 2 with required annotation
#   * check proteins (5701-5750): 1 with required annotation
#   * check proteins (5751-5800): 1 with required annotation
#   * check proteins (5801-5850): 1 with required annotation
#   * check proteins (5851-5900): 0 with required annotation
#   * check proteins (5901-5950): 0 with required annotation
#   * check proteins (5951-6000): 0 with required annotation
#   * check proteins (6001-6050): 0 with required annotation
#   * check proteins (6051-6100): 0 with required annotation
#   * check proteins (6101-6150): 0 with required annotation
#   * check proteins (6151-6200): 1 with required annotation
#   * check proteins (6201-6250): 1 with required annotation
#   * check proteins (6251-6300): 0 with required annotation
#   * check proteins (6301-6350): 0 with required annotation
#   * check proteins (6351-6400): 0 with required annotation
#   * check proteins (6401-6450): 0 with required annotation
#   * check proteins (6451-6500): 1 with required annotation
#   * check proteins (6501-6550): 1 with required annotation
#   * check proteins (6551-6600): 4 with required annotation
#   * check proteins (6601-6650): 8 with required annotation
#   * check proteins (6651-6700): 1 with required annotation
#   * check proteins (6701-6750): 4 with required annotation
#   * check proteins (6751-6800): 3 with required annotation
#   * check proteins (6801-6850): 2 with required annotation
#   * check proteins (6851-6900): 1 with required annotation
#   * check proteins (6901-6950): 0 with required annotation
#   * check proteins (6951-7000): 2 with required annotation
#   * check proteins (7001-7050): 1 with required annotation
#   * check proteins (7051-7100): 2 with required annotation
#   * check proteins (7101-7150): 1 with required annotation
#   * check proteins (7151-7200): 2 with required annotation
#   * check proteins (7201-7250): 1 with required annotation
#   * check proteins (7251-7300): 2 with required annotation
#   * check proteins (7301-7350): 4 with required annotation
#   * check proteins (7351-7400): 4 with required annotation
#   * check proteins (7401-7450): 2 with required annotation
#   * check proteins (7451-7500): 1 with required annotation
#   * check proteins (7501-7550): 1 with required annotation
#   * check proteins (7551-7600): 1 with required annotation
#   * check proteins (7601-7650): 3 with required annotation
#   * check proteins (7651-7700): 0 with required annotation
#   * check proteins (7701-7750): 0 with required annotation
#   * check proteins (7751-7800): 5 with required annotation
#   * check proteins (7801-7850): 0 with required annotation
#   * check proteins (7851-7900): 1 with required annotation
#   * check proteins (7901-7950): 0 with required annotation
#   * check proteins (7951-8000): 2 with required annotation
#   * check proteins (8001-8050): 1 with required annotation
#   * check proteins (8051-8100): 0 with required annotation
#   * check proteins (8101-8150): 0 with required annotation
#   * check proteins (8151-8200): 2 with required annotation
#   * check proteins (8201-8250): 2 with required annotation
#   * check proteins (8251-8300): 1 with required annotation
#   * check proteins (8301-8350): 2 with required annotation
#   * check proteins (8351-8400): 0 with required annotation
#   * check proteins (8401-8450): 0 with required annotation
#   * check proteins (8451-8500): 0 with required annotation
#   * check proteins (8501-8550): 1 with required annotation
#     -> Eumetazoa
#   * check proteins (8551-8600): 2 with required annotation
#   * check proteins (8601-8650): 0 with required annotation
#   * check proteins (8651-8700): 5 with required annotation
#   * check proteins (8701-8750): 2 with required annotation
#   * check proteins (8751-8800): 7 with required annotation
#   * check proteins (8801-8850): 5 with required annotation
#   * check proteins (8851-8900): 6 with required annotation
#   * check proteins (8901-8950): 1 with required annotation
#   * check proteins (8951-9000): 5 with required annotation
#   * check proteins (9001-9050): 2 with required annotation
#   * check proteins (9051-9100): 0 with required annotation
#   * check proteins (9101-9150): 1 with required annotation
#   * check proteins (9151-9200): 2 with required annotation
#   * check proteins (9201-9250): 0 with required annotation
#   * check proteins (9251-9300): 0 with required annotation
#   * check proteins (9301-9350): 5 with required annotation
#   * check proteins (9351-9400): 1 with required annotation
#   * check proteins (9401-9450): 0 with required annotation
#   * check proteins (9451-9500): 1 with required annotation
#   * check proteins (9501-9550): 1 with required annotation
#   * check proteins (9551-9600): 1 with required annotation
#   * check proteins (9601-9650): 3 with required annotation
#   * check proteins (9651-9700): 3 with required annotation
#   * check proteins (9701-9750): 2 with required annotation
#   * check proteins (9751-9800): 0 with required annotation
#   * check proteins (9801-9850): 1 with required annotation
#   * check proteins (9851-9900): 2 with required annotation
#   * check proteins (9901-9950): 0 with required annotation
#   * check proteins (9951-10000): 1 with required annotation
# - checked 9993 uniprot proteins: 325 with required annotation
#   -> for 325 of these 9993 items, reviewed is True
# - checked 10001 proteins: 13 linked to uniprot with required annotation
#   -> for 13 of these 10001 items reviewed is marked as True
# Search for Solyc01g094970.2
# - root is http://omabrowser.org/ontology/oma#GROUP_621909
# - tree of groups fetched: 231
# - proteins within tree fetched: 338
# - uniprot proteins within tree fetched: 247
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 0 with required annotation
#   * check proteins (151-200): 0 with required annotation
#   * check proteins (201-250): 0 with required annotation
# - checked 247 uniprot proteins: 0 with required annotation
# - checked 338 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094980.1
# - no groups found
# Search for Solyc01g094990.2
# - root is http://omabrowser.org/ontology/oma#GROUP_181431
# - tree of groups fetched: 135
# - proteins within tree fetched: 220
# - uniprot proteins within tree fetched: 165
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 0 with required annotation
#   * check proteins (151-200): 0 with required annotation
# - checked 165 uniprot proteins: 0 with required annotation
# - checked 220 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095000.2
# - root is http://omabrowser.org/ontology/oma#GROUP_431347
# - tree of groups fetched: 46
# - proteins within tree fetched: 64
# - uniprot proteins within tree fetched: 48
#   * check proteins (1-50): 0 with required annotation
# - checked 48 uniprot proteins: 0 with required annotation
# - checked 64 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095010.2
# - root is http://omabrowser.org/ontology/oma#GROUP_436849
# - tree of groups fetched: 344
# - proteins within tree fetched: 530
# - uniprot proteins within tree fetched: 365
#   * check proteins (1-50): 1 with required annotation
#     -> Carnivora
#   * check proteins (51-100): 2 with required annotation
#     -> Strepsirrhini, Murinae
#   * check proteins (101-150): 5 with required annotation
#     -> Metatheria, Archelosauria, Passeriformes, Laurasiatheria, Caniformia
#   * check proteins (151-200): 4 with required annotation
#     -> Phasianidae, Bovidae, Chiroptera, Cercopithecinae
#   * check proteins (201-250): 2 with required annotation
#     -> Lagomorpha, Bovidae
#   * check proteins (251-300): 5 with required annotation
#     -> Pan, Caniformia, Homininae, Hominidae, Murinae
#   * check proteins (301-350): 2 with required annotation
#     -> Afrotheria, Metatheria
#   * check proteins (351-400): 1 with required annotation
#     -> Caniformia
# - checked 365 uniprot proteins: 22 with required annotation
#   -> for 22 of these 365 items, reviewed is True
# - checked 530 proteins: 22 linked to uniprot with required annotation
#   -> for 22 of these 530 items reviewed is marked as True
# Search for Solyc01g095020.2
# - root is http://omabrowser.org/ontology/oma#GROUP_177224
# - tree of groups fetched: 42
# - proteins within tree fetched: 63
# - uniprot proteins within tree fetched: 43
#   * check proteins (1-50): 0 with required annotation
# - checked 43 uniprot proteins: 0 with required annotation
# - checked 63 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095030.2
# - root is http://omabrowser.org/ontology/oma#GROUP_422425
# - tree of groups fetched: 92
# - proteins within tree fetched: 142
# - uniprot proteins within tree fetched: 106
#   * check proteins (1-50): 46 with required annotation
#     -> Andropogoneae, Magnoliophyta, Phaseoleae, Oryza, Brassicaceae, Oryza sativa, Malvaceae, Brassica, Triticinae, Arabidopsis, Gossypium, Ostreococcus, Triticeae, Pooideae, Pentapetalae, commelinids
#   * check proteins (51-100): 45 with required annotation
#     -> Pentapetalae, Oryza, Triticinae, Solanaceae, Phaseoleae, Malvaceae, Solanum, Gossypium, 50 kb inversion clade, Panicoideae, Oryza sativa, Ostreococcus, rosids, Triticum, fabids, Eukaryota, Brassica
#   * check proteins (101-142): 5 with required annotation
#     -> Oryza, Solanum
# - checked 106 uniprot proteins: 96 with required annotation
#   -> for 96 of these 106 items, reviewed is True
# - checked 142 proteins: 95 linked to uniprot with required annotation
#   -> for 95 of these 142 items reviewed is marked as True
# Search for Solyc01g095040.2
# - root is http://omabrowser.org/ontology/oma#GROUP_182244
# - tree of groups fetched: 54
# - proteins within tree fetched: 78
# - uniprot proteins within tree fetched: 61
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-78): 0 with required annotation
# - checked 61 uniprot proteins: 0 with required annotation
# - checked 78 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095050.2
# - root is http://omabrowser.org/ontology/oma#GROUP_175428
# - tree of groups fetched: 31
# - proteins within tree fetched: 43
# - uniprot proteins within tree fetched: 30
#   * check proteins (1-43): 0 with required annotation
# - checked 30 uniprot proteins: 0 with required annotation
# - checked 43 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095060.2
# - root is http://omabrowser.org/ontology/oma#GROUP_168460
# - tree of groups fetched: 2
# - proteins within tree fetched: 3
# - uniprot proteins within tree fetched: 3
#   * check proteins (1-3): 0 with required annotation
# - checked 3 uniprot proteins: 0 with required annotation
# - checked 3 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095070.2
# - root is http://omabrowser.org/ontology/oma#GROUP_170343
# - tree of groups fetched: 52
# - proteins within tree fetched: 85
# - uniprot proteins within tree fetched: 61
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-85): 0 with required annotation
# - checked 61 uniprot proteins: 0 with required annotation
# - checked 85 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095080.2
# - root is http://omabrowser.org/ontology/oma#GROUP_436892
# - tree of groups fetched: 2089
# - proteins within tree fetched: 3327
# - uniprot proteins within tree fetched: 2325
#   * check proteins (1-50): 0 with required annotation
#   * check proteins (51-100): 0 with required annotation
#   * check proteins (101-150): 0 with required annotation
#   * check proteins (151-200): 0 with required annotation
#   * check proteins (201-250): 0 with required annotation
#   * check proteins (251-300): 0 with required annotation
#   * check proteins (301-350): 0 with required annotation
#   * check proteins (351-400): 0 with required annotation
#   * check proteins (401-450): 0 with required annotation
#   * check proteins (451-500): 0 with required annotation
#   * check proteins (501-550): 0 with required annotation
#   * check proteins (551-600): 2 with required annotation
#     -> Phytophthora, Oomycetes
#   * check proteins (601-650): 0 with required annotation
#   * check proteins (651-700): 0 with required annotation
#   * check proteins (701-750): 0 with required annotation
#   * check proteins (751-800): 0 with required annotation
#   * check proteins (801-850): 0 with required annotation
#   * check proteins (851-900): 0 with required annotation
#   * check proteins (901-950): 0 with required annotation
#   * check proteins (951-1000): 0 with required annotation
#   * check proteins (1001-1050): 0 with required annotation
#   * check proteins (1051-1100): 0 with required annotation
#   * check proteins (1101-1150): 0 with required annotation
#   * check proteins (1151-1200): 0 with required annotation
#   * check proteins (1201-1250): 0 with required annotation
#   * check proteins (1251-1300): 1 with required annotation
#     -> Phytophthora
#   * check proteins (1301-1350): 0 with required annotation
#   * check proteins (1351-1400): 0 with required annotation
#   * check proteins (1401-1450): 0 with required annotation
#   * check proteins (1451-1500): 0 with required annotation
#   * check proteins (1501-1550): 0 with required annotation
#   * check proteins (1551-1600): 0 with required annotation
#   * check proteins (1601-1650): 0 with required annotation
#   * check proteins (1651-1700): 0 with required annotation
#   * check proteins (1701-1750): 0 with required annotation
#   * check proteins (1751-1800): 0 with required annotation
#   * check proteins (1801-1850): 0 with required annotation
#   * check proteins (1851-1900): 0 with required annotation
#   * check proteins (1901-1950): 0 with required annotation
#   * check proteins (1951-2000): 0 with required annotation
#   * check proteins (2001-2050): 0 with required annotation
#   * check proteins (2051-2100): 0 with required annotation
#   * check proteins (2101-2150): 0 with required annotation
#   * check proteins (2151-2200): 0 with required annotation
#   * check proteins (2201-2250): 0 with required annotation
#   * check proteins (2251-2300): 0 with required annotation
#   * check proteins (2301-2350): 0 with required annotation
# - checked 2325 uniprot proteins: 3 with required annotation
#   -> for 3 of these 2325 items, reviewed is True
# - checked 3327 proteins: 3 linked to uniprot with required annotation
#   -> for 3 of these 3327 items reviewed is marked as True
# === COMPUTATIONS ===
# Compute for Solyc01g094700.2
# Skip Solyc01g094710.1
# Compute for Solyc01g094720.2
# Skip Solyc01g094740.1
# Compute for Solyc01g094750.2
# Compute for Solyc01g094760.2
# Compute for Solyc01g094770.2
# Compute for Solyc01g094780.2
# Compute for Solyc01g094790.2
# Compute for Solyc01g094800.2
# Compute for Solyc01g094810.2
# Compute for Solyc01g094820.2
# Compute for Solyc01g094830.2
# Compute for Solyc01g094840.2
# Compute for Solyc01g094850.1
# Compute for Solyc01g094860.2
# Compute for Solyc01g094870.1
# Compute for Solyc01g094880.2
# Compute for Solyc01g094890.2
# Compute for Solyc01g094900.1
# Compute for Solyc01g094910.2
# Compute for Solyc01g094920.2
# Compute for Solyc01g094930.2
# Compute for Solyc01g094940.2
# Compute for Solyc01g094950.2
# Compute for Solyc01g094960.2
# Compute for Solyc01g094970.2
# Skip Solyc01g094980.1
# Compute for Solyc01g094990.2
# Compute for Solyc01g095000.2
# Compute for Solyc01g095010.2
# Compute for Solyc01g095020.2
# Compute for Solyc01g095030.2
# Compute for Solyc01g095040.2
# Compute for Solyc01g095050.2
# Compute for Solyc01g095060.2
# Compute for Solyc01g095070.2
# Compute for Solyc01g095080.2
# === CREATED QTLSEARCH OBJECT ===

# %% [markdown]
# Create report

# %%
report_list = result.report()
for report in report_list:
    display(report)
# Out:
#                   p_initial    p_final  \
# gene
# Solyc01g095030.2   0.026316  20.423493
# Solyc01g094820.2   0.026316   3.715449
# Solyc01g094800.2   0.026316   1.800694
# Solyc01g094760.2   0.026316   1.258382
# Solyc01g094810.2   0.026316   0.241966
# Solyc01g095080.2   0.026316   0.145123
# Solyc01g095010.2   0.026316   0.096375
# Solyc01g094930.2   0.026316   0.060635
# Solyc01g094700.2   0.026316   0.026316
# Solyc01g094770.2   0.026316   0.026316
# Solyc01g094780.2   0.026316   0.026316
# Solyc01g094790.2   0.026316   0.026316
# Solyc01g094830.2   0.026316   0.026316
# Solyc01g094840.2   0.026316   0.026316
# Solyc01g094850.1   0.026316   0.026316
# Solyc01g094860.2   0.026316   0.026316
# Solyc01g094870.1   0.026316   0.026316
# Solyc01g094880.2   0.026316   0.026316
# Solyc01g094890.2   0.026316   0.026316
# Solyc01g094900.1   0.026316   0.026316
# Solyc01g094910.2   0.026316   0.026316
# Solyc01g094920.2   0.026316   0.026316
# Solyc01g094940.2   0.026316   0.026316
# Solyc01g094950.2   0.026316   0.026316
# Solyc01g094970.2   0.026316   0.026316
# Solyc01g094990.2   0.026316   0.026316
# Solyc01g095000.2   0.026316   0.026316
# Solyc01g095020.2   0.026316   0.026316
# Solyc01g095040.2   0.026316   0.026316
# Solyc01g095050.2   0.026316   0.026316
# Solyc01g095060.2   0.026316   0.026316
# Solyc01g095070.2   0.026316   0.026316
# Solyc01g094720.2   0.026316   0.000000
# Solyc01g094750.2   0.026316   0.000000
# Solyc01g094960.2   0.026316   0.000000
#
#                                                      protein
# gene
# Solyc01g095030.2  https://omabrowser.org/oma/info/SOLLC02643
# Solyc01g094820.2  https://omabrowser.org/oma/info/SOLLC02622
# Solyc01g094800.2  https://omabrowser.org/oma/info/SOLLC02620
# Solyc01g094760.2  https://omabrowser.org/oma/info/SOLLC02616
# Solyc01g094810.2  https://omabrowser.org/oma/info/SOLLC02621
# Solyc01g095080.2  https://omabrowser.org/oma/info/SOLLC02648
# Solyc01g095010.2  https://omabrowser.org/oma/info/SOLLC02641
# Solyc01g094930.2  https://omabrowser.org/oma/info/SOLLC02633
# Solyc01g094700.2  https://omabrowser.org/oma/info/SOLLC02611
# Solyc01g094770.2  https://omabrowser.org/oma/info/SOLLC02617
# Solyc01g094780.2  https://omabrowser.org/oma/info/SOLLC02618
# Solyc01g094790.2  https://omabrowser.org/oma/info/SOLLC02619
# Solyc01g094830.2  https://omabrowser.org/oma/info/SOLLC02623
# Solyc01g094840.2  https://omabrowser.org/oma/info/SOLLC02624
# Solyc01g094850.1  https://omabrowser.org/oma/info/SOLLC02625
# Solyc01g094860.2  https://omabrowser.org/oma/info/SOLLC02626
# Solyc01g094870.1  https://omabrowser.org/oma/info/SOLLC02627
# Solyc01g094880.2  https://omabrowser.org/oma/info/SOLLC02628
# Solyc01g094890.2  https://omabrowser.org/oma/info/SOLLC02629
# Solyc01g094900.1  https://omabrowser.org/oma/info/SOLLC02630
# Solyc01g094910.2  https://omabrowser.org/oma/info/SOLLC02631
# Solyc01g094920.2  https://omabrowser.org/oma/info/SOLLC02632
# Solyc01g094940.2  https://omabrowser.org/oma/info/SOLLC02634
# Solyc01g094950.2  https://omabrowser.org/oma/info/SOLLC02635
# Solyc01g094970.2  https://omabrowser.org/oma/info/SOLLC02637
# Solyc01g094990.2  https://omabrowser.org/oma/info/SOLLC02639
# Solyc01g095000.2  https://omabrowser.org/oma/info/SOLLC02640
# Solyc01g095020.2  https://omabrowser.org/oma/info/SOLLC02642
# Solyc01g095040.2  https://omabrowser.org/oma/info/SOLLC02644
# Solyc01g095050.2  https://omabrowser.org/oma/info/SOLLC02645
# Solyc01g095060.2  https://omabrowser.org/oma/info/SOLLC02646
# Solyc01g095070.2  https://omabrowser.org/oma/info/SOLLC02647
# Solyc01g094720.2  https://omabrowser.org/oma/info/SOLLC02613
# Solyc01g094750.2  https://omabrowser.org/oma/info/SOLLC02615
# Solyc01g094960.2  https://omabrowser.org/oma/info/SOLLC02636
