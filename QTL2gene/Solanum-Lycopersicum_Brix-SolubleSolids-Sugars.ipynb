# %% [markdown]
# **Implementation algorithm**
#
# Prioritization of candidate genes in QTL regions based on associations between traits and biological processes.
# Bargsten JW, Nap JP, Sanchez-Perez GF, van Dijk AD.
# BMC Plant Biol. 2014 Dec 10;14:330. doi: 10.1186/s12870-014-0330-3.

# %%
import qtl2gene
import pandas as pd
search = qtl2gene.SEARCH(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl:8890/sparql")

# %% [markdown]
# ## Brix, Soluble Solids, Sugars
#
# Trait:
#
# QTL from: Chromosome `9`, around `3474710`
#
# Candidate: `Lin5` (`Solyc09g010080`)

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
d=100000
p=3474710
interval = search.make_interval(
    "http://localhost:8890/genome/Solanum_lycopersicum/chromosome/9",
    p-d, 
    p+d)

#genes for interval
genes = search.interval_genes(interval)
#goterms for genes
goterms = search.genes_goterms(genes["gene_id"].unique())
#compute the numbers 
gonumbers = search.get_go_numbers(goterms, genes)

# %% [markdown]
# Number of genes found in QTL

# %%
len(genes)
#pd.DataFrame(goterms.groupby(["go_id","go_cat","go_term"])["gene_id"].count())
# Out:
# 29

# %% [markdown]
# GO terms with boundary on adjusted p-value

# %%
p_boundary = 0.1
selection = gonumbers[gonumbers["p_adjusted"]<p_boundary]
pd.DataFrame(selection)[["p_less", "p_greater", "p_adjusted"]]
# Out:
#               p_less  p_greater  p_adjusted
# go_id
# GO:0000028  0.999371   0.036274    0.066147
# GO:0000462  0.999217   0.040409    0.069593
# GO:0005975  0.997593   0.029466    0.060896
# GO:0006260  0.999509   0.032123    0.062238
# GO:0006310  0.998101   0.062441    0.092175
# GO:0006486  0.997681   0.068875    0.092832
# GO:0006614  0.999961   0.009403    0.026488
# GO:0006839  0.998859   0.048627    0.079338
# GO:0007018  0.997681   0.068875    0.092832
# GO:0009736  0.999953   0.010254    0.026488
# GO:0009740  0.999892   0.015342    0.036585
# GO:0009938  0.999996   0.003429    0.015187
# GO:0016554  0.999980   0.006847    0.021226
# GO:0016567  0.998481   0.055965    0.086745
# GO:0019878  0.999996   0.003429    0.015187
# GO:0032511  0.999999   0.001716    0.010639
# GO:0032543  0.999837   0.018721    0.041453
# GO:0034059  1.000000   0.000858    0.010639
# GO:0050821  0.999985   0.005994    0.021226
# GO:0070208  1.000000   0.000858    0.010639
# GO:1904143  0.999999   0.001716    0.010639
# GO:2000009  0.999999   0.001716    0.010639
# GO:2000377  0.999980   0.006847    0.021226

# %% [markdown]
# Genes with at least one of these GO terms, sorted descending by number of GO terms

# %%
geneSelection = pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))].groupby("gene_id")["gene_id"].count())
geneSelection.columns = ["#go-terms"]
geneSelection = geneSelection.sort_values(by="#go-terms", ascending=False)
display(geneSelection)
# Out:
#                   #go-terms
# gene_id
# Solyc09g010180.2          5
# Solyc09g009900.2          2
# Solyc09g009940.2          2
# Solyc09g010030.1          2
# Solyc09g010100.2          2
# Solyc09g010110.2          2
# Solyc09g010170.2          2
# Solyc09g009950.2          1
# Solyc09g009960.2          1
# Solyc09g009970.2          1
# Solyc09g010050.1          1
# Solyc09g010060.2          1
# Solyc09g010080.2          1
# Solyc09g010090.2          1

# %%
pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))]).groupby(["gene_id","go_id"]).sum()[["go_term","go_cat"]]
# Out:
#                                                                        go_term  \
# gene_id          go_id
# Solyc09g009900.2 GO:0006260                                    DNA replication
#                  GO:0006310                                  DNA recombination
# Solyc09g009940.2 GO:0006614  SRP-dependent cotranslational protein targetin...
#                  GO:0070208                        protein heterotrimerization
# Solyc09g009950.2 GO:0016554                        cytidine to uridine editing
# Solyc09g009960.2 GO:0019878   lysine biosynthetic process via aminoadipic acid
# Solyc09g009970.2 GO:0034059                                 response to anoxia
# Solyc09g010030.1 GO:0006839                            mitochondrial transport
#                  GO:0032543                          mitochondrial translation
# Solyc09g010050.1 GO:0016567                             protein ubiquitination
# Solyc09g010060.2 GO:0007018                         microtubule-based movement
# Solyc09g010080.2 GO:0005975                     carbohydrate metabolic process
# Solyc09g010090.2 GO:0005975                     carbohydrate metabolic process
# Solyc09g010100.2 GO:0000028                   ribosomal small subunit assembly
#                  GO:0000462  maturation of SSU-rRNA from tricistronic rRNA ...
# Solyc09g010110.2 GO:0050821                              protein stabilization
#                  GO:1904143  positive regulation of carotenoid biosynthetic...
# Solyc09g010170.2 GO:0032511  late endosome to vacuole transport via multive...
#                  GO:2000009  negative regulation of protein localization to...
# Solyc09g010180.2 GO:0006486                              protein glycosylation
#                  GO:0009736              cytokinin-activated signaling pathway
#                  GO:0009740        gibberellic acid mediated signaling pathway
#                  GO:0009938  negative regulation of gibberellic acid mediat...
#                  GO:2000377  regulation of reactive oxygen species metaboli...
#
#                                          go_cat
# gene_id          go_id
# Solyc09g009900.2 GO:0006260  biological_process
#                  GO:0006310  biological_process
# Solyc09g009940.2 GO:0006614  biological_process
#                  GO:0070208  biological_process
# Solyc09g009950.2 GO:0016554  biological_process
# Solyc09g009960.2 GO:0019878  biological_process
# Solyc09g009970.2 GO:0034059  biological_process
# Solyc09g010030.1 GO:0006839  biological_process
#                  GO:0032543  biological_process
# Solyc09g010050.1 GO:0016567  biological_process
# Solyc09g010060.2 GO:0007018  biological_process
# Solyc09g010080.2 GO:0005975  biological_process
# Solyc09g010090.2 GO:0005975  biological_process
# Solyc09g010100.2 GO:0000028  biological_process
#                  GO:0000462  biological_process
# Solyc09g010110.2 GO:0050821  biological_process
#                  GO:1904143  biological_process
# Solyc09g010170.2 GO:0032511  biological_process
#                  GO:2000009  biological_process
# Solyc09g010180.2 GO:0006486  biological_process
#                  GO:0009736  biological_process
#                  GO:0009740  biological_process
#                  GO:0009938  biological_process
#                  GO:2000377  biological_process
