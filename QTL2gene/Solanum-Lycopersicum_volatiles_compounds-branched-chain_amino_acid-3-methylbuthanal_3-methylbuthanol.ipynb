# %% [markdown]
# **Implementation algorithm**
#
# Prioritization of candidate genes in QTL regions based on associations between traits and biological processes.
# Bargsten JW, Nap JP, Sanchez-Perez GF, van Dijk AD.
# BMC Plant Biol. 2014 Dec 10;14:330. doi: 10.1186/s12870-014-0330-3.

# %%
import qtl2gene
import pandas as pd
search = qtl2gene.SEARCH(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl:8890/sparql")

# %% [markdown]
# ## Volatiles compounds, branched-chain amino acid, 3-methylbuthanal 3-methylbuthanol
#
# GO-terms: GO:0046568, GO:0018455, GO:0052676
#
# QTL from: Chromosome 3 : 69685329 - 71362039
#
# Candidate: ???

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
interval = search.make_interval(
    "http://localhost:8890/genome/Solanum_lycopersicum/chromosome/3", 
    69685329,71362039)

#genes for interval
genes = search.interval_genes(interval)
#goterms for genes
goterms = search.genes_goterms(genes["gene_id"].unique())
#compute the numbers 
gonumbers = search.get_go_numbers(goterms, genes)

# %% [markdown]
# Number of genes found in QTL

# %%
len(genes)
#pd.DataFrame(goterms.groupby(["go_id","go_cat","go_term"])["gene_id"].count())
# Out:
# 148

# %% [markdown]
# GO terms with boundary on adjusted p-value

# %%
p_boundary = 0.1
selection = gonumbers[gonumbers["p_adjusted"]<p_boundary]
pd.DataFrame(selection)[["p_less", "p_greater", "p_adjusted"]]
# Out:
#               p_less  p_greater  p_adjusted
# go_id
# GO:0000209  0.998923   0.010311    0.098639
# GO:0007338  1.000000   0.004381    0.088981
# GO:0009767  0.999863   0.004540    0.088981
# GO:0010014  0.999943   0.013085    0.098639
# GO:0010603  0.999943   0.013085    0.098639
# GO:0018008  0.999981   0.008742    0.098639
# GO:0030433  0.999723   0.007161    0.098639
# GO:0031627  0.999911   0.003439    0.088981
# GO:0036092  0.999943   0.013085    0.098639
# GO:0045041  0.999943   0.013085    0.098639
# GO:0070455  1.000000   0.004381    0.088981
# GO:0071528  1.000000   0.004381    0.088981
# GO:2000032  0.999981   0.008742    0.098639

# %% [markdown]
# Genes with at least one of these GO terms, sorted descending by number of GO terms

# %%
geneSelection = pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))].groupby("gene_id")["gene_id"].count())
geneSelection.columns = ["#go-terms"]
geneSelection = geneSelection.sort_values(by="#go-terms", ascending=False)
display(geneSelection)
# Out:
#                   #go-terms
# gene_id
# Solyc03g122370.2          2
# Solyc03g123660.2          2
# Solyc03g123880.2          2
# Solyc03g121640.2          1
# Solyc03g121690.1          1
# Solyc03g121830.1          1
# Solyc03g121840.2          1
# Solyc03g121950.2          1
# Solyc03g121990.2          1
# Solyc03g122000.2          1
# Solyc03g123400.1          1
# Solyc03g123480.1          1
# Solyc03g123520.2          1
# Solyc03g123730.2          1
# Solyc03g123890.2          1

# %%
pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))]).groupby(["gene_id","go_id"]).sum()[["go_term","go_cat"]]
# Out:
#                                                                        go_term  \
# gene_id          go_id
# Solyc03g121640.2 GO:0045041  protein import into mitochondrial intermembran...
# Solyc03g121690.1 GO:0000209                         protein polyubiquitination
# Solyc03g121830.1 GO:0018008       N-terminal peptidyl-glycine N-myristoylation
# Solyc03g121840.2 GO:0031627                           telomeric loop formation
# Solyc03g121950.2 GO:0010603  regulation of cytoplasmic mRNA processing body...
# Solyc03g121990.2 GO:0031627                           telomeric loop formation
# Solyc03g122000.2 GO:0009767            photosynthetic electron transport chain
# Solyc03g122370.2 GO:0010014                                meristem initiation
#                  GO:0071528                        tRNA re-export from nucleus
# Solyc03g123400.1 GO:2000032            regulation of secondary shoot formation
# Solyc03g123480.1 GO:0000209                         protein polyubiquitination
# Solyc03g123520.2 GO:0036092  phosphatidylinositol-3-phosphate biosynthetic ...
# Solyc03g123660.2 GO:0000209                         protein polyubiquitination
#                  GO:0030433                   ubiquitin-dependent ERAD pathway
# Solyc03g123730.2 GO:0030433                   ubiquitin-dependent ERAD pathway
# Solyc03g123880.2 GO:0009767            photosynthetic electron transport chain
#                  GO:0070455   positive regulation of heme biosynthetic process
# Solyc03g123890.2 GO:0007338                               single fertilization
#
#                                          go_cat
# gene_id          go_id
# Solyc03g121640.2 GO:0045041  biological_process
# Solyc03g121690.1 GO:0000209  biological_process
# Solyc03g121830.1 GO:0018008  biological_process
# Solyc03g121840.2 GO:0031627  biological_process
# Solyc03g121950.2 GO:0010603  biological_process
# Solyc03g121990.2 GO:0031627  biological_process
# Solyc03g122000.2 GO:0009767  biological_process
# Solyc03g122370.2 GO:0010014  biological_process
#                  GO:0071528  biological_process
# Solyc03g123400.1 GO:2000032  biological_process
# Solyc03g123480.1 GO:0000209  biological_process
# Solyc03g123520.2 GO:0036092  biological_process
# Solyc03g123660.2 GO:0000209  biological_process
#                  GO:0030433  biological_process
# Solyc03g123730.2 GO:0030433  biological_process
# Solyc03g123880.2 GO:0009767  biological_process
#                  GO:0070455  biological_process
# Solyc03g123890.2 GO:0007338  biological_process
