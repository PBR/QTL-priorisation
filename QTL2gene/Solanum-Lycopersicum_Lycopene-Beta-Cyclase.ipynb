# %% [markdown]
# **Implementation algorithm**
#
# Prioritization of candidate genes in QTL regions based on associations between traits and biological processes.
# Bargsten JW, Nap JP, Sanchez-Perez GF, van Dijk AD.
# BMC Plant Biol. 2014 Dec 10;14:330. doi: 10.1186/s12870-014-0330-3.

# %%
import qtl2gene
import pandas as pd
search = qtl2gene.SEARCH(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl:8890/sparql")

# %% [markdown]
# ## Lycopene-Beta-Cyclase Activity
#
# GO-terms: GO:0045436 GP:0016117
#
# QTL from: Solyc06g073470.2 ... Solyc06g083850.2
#
# Candidate: Solyc06g074240.1

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
tg1 = "Solyc06g073470.2"
tg2 = "Solyc06g083850.2"

#intervalT = search.compute_interval(tg1, tg2)

interval = search.make_interval(
    "http://localhost:8890/genome/Solanum_lycopersicum/chromosome/6",
    45280179,
    49150528)

#genes for interval
genes = search.interval_genes(interval)
#goterms for genes
goterms = search.genes_goterms(genes["gene_id"].unique())
#compute the numbers 
gonumbers = search.get_go_numbers(goterms, genes)

# %% [markdown]
# Number of genes found in QTL

# %%
len(genes)
#pd.DataFrame(goterms.groupby(["go_id","go_cat","go_term"])["gene_id"].count())
# Out:
# 535

# %% [markdown]
# GO terms with boundary on adjusted p-value

# %%
p_boundary = 0.1
selection = gonumbers[gonumbers["p_adjusted"]<p_boundary]
pd.DataFrame(selection)[["p_less", "p_greater", "p_adjusted"]]
# Out:
#               p_less  p_greater  p_adjusted
# go_id
# GO:0006412  0.999324   0.001850    0.057568
# GO:0006857  0.999839   0.001768    0.057568
# GO:0009251  1.000000   0.000012    0.003014
# GO:0010345  0.999981   0.000593    0.029514
# GO:0019748  0.999968   0.000514    0.029514
# GO:0030433  0.999995   0.000085    0.010552
# GO:0031047  0.999977   0.000280    0.023267
# GO:0045899  0.999945   0.001262    0.052372

# %% [markdown]
# Genes with at least one of these GO terms, sorted descending by number of GO terms

# %%
geneSelection = pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))].groupby("gene_id")["gene_id"].count())
geneSelection.columns = ["#go-terms"]
geneSelection = geneSelection.sort_values(by="#go-terms", ascending=False)
display(geneSelection)
# Out:
#                   #go-terms
# gene_id
# Solyc06g083620.2          2
# Solyc06g082630.2          2
# Solyc06g082660.2          2
# Solyc06g073530.1          1
# Solyc06g082750.2          1
# Solyc06g076780.2          1
# Solyc06g076800.2          1
# Solyc06g082140.2          1
# Solyc06g082650.2          1
# Solyc06g082670.2          1
# Solyc06g082760.2          1
# Solyc06g073540.2          1
# Solyc06g082870.2          1
# Solyc06g083020.1          1
# Solyc06g083030.2          1
# Solyc06g083040.2          1
# Solyc06g083050.2          1
# Solyc06g083180.2          1
# Solyc06g083780.2          1
# Solyc06g076750.2          1
# Solyc06g076210.1          1
# Solyc06g076200.1          1
# Solyc06g074390.2          1
# Solyc06g073740.2          1
# Solyc06g073750.2          1
# Solyc06g073760.2          1
# Solyc06g073790.2          1
# Solyc06g073800.2          1
# Solyc06g073880.2          1
# Solyc06g074300.2          1
# Solyc06g074410.2          1
# Solyc06g076010.2          1
# Solyc06g074730.2          1
# Solyc06g074770.2          1
# Solyc06g075180.1          1
# Solyc06g075440.1          1
# Solyc06g075490.1          1
# Solyc06g075500.2          1
# Solyc06g075620.2          1
# Solyc06g083820.2          1

# %%
pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))]).groupby(["gene_id","go_id"]).sum()[["go_term","go_cat"]]
# Out:
#                                                                        go_term  \
# gene_id          go_id
# Solyc06g073530.1 GO:0031047                              gene silencing by RNA
# Solyc06g073540.2 GO:0031047                              gene silencing by RNA
# Solyc06g073740.2 GO:0009251                           glucan catabolic process
# Solyc06g073750.2 GO:0009251                           glucan catabolic process
# Solyc06g073760.2 GO:0009251                           glucan catabolic process
# Solyc06g073790.2 GO:0006412                                        translation
# Solyc06g073800.2 GO:0006412                                        translation
# Solyc06g073880.2 GO:0030433                   ubiquitin-dependent ERAD pathway
# Solyc06g074300.2 GO:0006412                                        translation
# Solyc06g074390.2 GO:0010345                       suberin biosynthetic process
# Solyc06g074410.2 GO:0010345                       suberin biosynthetic process
# Solyc06g074730.2 GO:0031047                              gene silencing by RNA
# Solyc06g074770.2 GO:0030433                   ubiquitin-dependent ERAD pathway
# Solyc06g075180.1 GO:0006412                                        translation
# Solyc06g075440.1 GO:0006857                             oligopeptide transport
# Solyc06g075490.1 GO:0006857                             oligopeptide transport
# Solyc06g075500.2 GO:0006857                             oligopeptide transport
# Solyc06g075620.2 GO:0006412                                        translation
# Solyc06g076010.2 GO:0006412                                        translation
# Solyc06g076200.1 GO:0031047                              gene silencing by RNA
# Solyc06g076210.1 GO:0031047                              gene silencing by RNA
# Solyc06g076750.2 GO:0006857                             oligopeptide transport
# Solyc06g076780.2 GO:0009251                           glucan catabolic process
# Solyc06g076800.2 GO:0010345                       suberin biosynthetic process
# Solyc06g082140.2 GO:0006412                                        translation
# Solyc06g082630.2 GO:0030433                   ubiquitin-dependent ERAD pathway
#                  GO:0045899  positive regulation of RNA polymerase II trans...
# Solyc06g082650.2 GO:0006412                                        translation
# Solyc06g082660.2 GO:0030433                   ubiquitin-dependent ERAD pathway
#                  GO:0045899  positive regulation of RNA polymerase II trans...
# Solyc06g082670.2 GO:0006412                                        translation
# Solyc06g082750.2 GO:0006412                                        translation
# Solyc06g082760.2 GO:0006412                                        translation
# Solyc06g082870.2 GO:0006412                                        translation
# Solyc06g083020.1 GO:0019748                        secondary metabolic process
# Solyc06g083030.2 GO:0019748                        secondary metabolic process
# Solyc06g083040.2 GO:0019748                        secondary metabolic process
# Solyc06g083050.2 GO:0019748                        secondary metabolic process
# Solyc06g083180.2 GO:0006412                                        translation
# Solyc06g083620.2 GO:0030433                   ubiquitin-dependent ERAD pathway
#                  GO:0045899  positive regulation of RNA polymerase II trans...
# Solyc06g083780.2 GO:0006412                                        translation
# Solyc06g083820.2 GO:0006412                                        translation
#
#                                          go_cat
# gene_id          go_id
# Solyc06g073530.1 GO:0031047  biological_process
# Solyc06g073540.2 GO:0031047  biological_process
# Solyc06g073740.2 GO:0009251  biological_process
# Solyc06g073750.2 GO:0009251  biological_process
# Solyc06g073760.2 GO:0009251  biological_process
# Solyc06g073790.2 GO:0006412  biological_process
# Solyc06g073800.2 GO:0006412  biological_process
# Solyc06g073880.2 GO:0030433  biological_process
# Solyc06g074300.2 GO:0006412  biological_process
# Solyc06g074390.2 GO:0010345  biological_process
# Solyc06g074410.2 GO:0010345  biological_process
# Solyc06g074730.2 GO:0031047  biological_process
# Solyc06g074770.2 GO:0030433  biological_process
# Solyc06g075180.1 GO:0006412  biological_process
# Solyc06g075440.1 GO:0006857  biological_process
# Solyc06g075490.1 GO:0006857  biological_process
# Solyc06g075500.2 GO:0006857  biological_process
# Solyc06g075620.2 GO:0006412  biological_process
# Solyc06g076010.2 GO:0006412  biological_process
# Solyc06g076200.1 GO:0031047  biological_process
# Solyc06g076210.1 GO:0031047  biological_process
# Solyc06g076750.2 GO:0006857  biological_process
# Solyc06g076780.2 GO:0009251  biological_process
# Solyc06g076800.2 GO:0010345  biological_process
# Solyc06g082140.2 GO:0006412  biological_process
# Solyc06g082630.2 GO:0030433  biological_process
#                  GO:0045899  biological_process
# Solyc06g082650.2 GO:0006412  biological_process
# Solyc06g082660.2 GO:0030433  biological_process
#                  GO:0045899  biological_process
# Solyc06g082670.2 GO:0006412  biological_process
# Solyc06g082750.2 GO:0006412  biological_process
# Solyc06g082760.2 GO:0006412  biological_process
# Solyc06g082870.2 GO:0006412  biological_process
# Solyc06g083020.1 GO:0019748  biological_process
# Solyc06g083030.2 GO:0019748  biological_process
# Solyc06g083040.2 GO:0019748  biological_process
# Solyc06g083050.2 GO:0019748  biological_process
# Solyc06g083180.2 GO:0006412  biological_process
# Solyc06g083620.2 GO:0030433  biological_process
#                  GO:0045899  biological_process
# Solyc06g083780.2 GO:0006412  biological_process
# Solyc06g083820.2 GO:0006412  biological_process
