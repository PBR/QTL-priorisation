# %% [markdown]
# **Implementation algorithm**
#
# Prioritization of candidate genes in QTL regions based on associations between traits and biological processes.
# Bargsten JW, Nap JP, Sanchez-Perez GF, van Dijk AD.
# BMC Plant Biol. 2014 Dec 10;14:330. doi: 10.1186/s12870-014-0330-3.

# %%
import qtl2gene
import pandas as pd
search = qtl2gene.SEARCH(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl:8890/sparql")

# %% [markdown]
# ## Terpenoids
#
# GO-terms: GO:0003677, GO:0045893
#
# QTL from: Chromosome 1 : 86142248 - 86467672
#
# Candidate: Terpense synthase

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
interval = search.make_interval(
    "http://localhost:8890/genome/Solanum_lycopersicum/chromosome/1",
    86142248,
    86467672)

#genes for interval
genes = search.interval_genes(interval)
#goterms for genes
goterms = search.genes_goterms(genes["gene_id"].unique())
#compute the numbers 
gonumbers = search.get_go_numbers(goterms, genes)

# %% [markdown]
# Number of genes found in QTL

# %%
len(genes)
#pd.DataFrame(goterms.groupby(["go_id","go_cat","go_term"])["gene_id"].count())
# Out:
# 38

# %% [markdown]
# GO terms with boundary on adjusted p-value

# %%
p_boundary = 0.1
selection = gonumbers[gonumbers["p_adjusted"]<p_boundary]
pd.DataFrame(selection)[["p_less", "p_greater", "p_adjusted"]]
# Out:
#               p_less  p_greater  p_adjusted
# go_id
# GO:0000226  0.999769   0.022263    0.036280
# GO:0006270  0.999792   0.021161    0.035811
# GO:0006535  0.999905   0.014526    0.028664
# GO:0008360  0.999693   0.025560    0.040166
# GO:0009693  0.999956   0.010079    0.023340
# GO:0009744  0.999872   0.016743    0.029467
# GO:0009835  0.999933   0.012305    0.027071
# GO:0009965  0.999966   0.008964    0.021911
# GO:0010091  1.000000   0.001125    0.007070
# GO:0010143  0.999905   0.014526    0.028664
# GO:0010199  0.999999   0.002248    0.008993
# GO:0010468  0.998174   0.061125    0.089651
# GO:0010482  1.000000   0.001125    0.007070
# GO:0016311  0.999889   0.015635    0.028664
# GO:0019499  0.999996   0.003371    0.010593
# GO:0031129  1.000000   0.001125    0.007070
# GO:0034063  0.999993   0.004492    0.012352
# GO:0035308  0.999996   0.003371    0.010593
# GO:0040029  0.999999   0.002248    0.008993
# GO:0042147  0.999439   0.034301    0.052042
# GO:0042814  0.999999   0.002248    0.008993
# GO:0043044  0.999982   0.006730    0.017419
# GO:0045604  1.000000   0.001125    0.007070
# GO:0046916  0.997623   0.069555    0.095638
# GO:0048444  0.999993   0.004492    0.012352
# GO:0048530  0.999999   0.002248    0.008993
# GO:0048544  0.997623   0.069555    0.095638
# GO:0071586  0.999996   0.003371    0.010593
# GO:0098656  0.999889   0.015635    0.028664
# GO:1900036  1.000000   0.001125    0.007070
# GO:1903798  1.000000   0.001125    0.007070
# GO:2000039  1.000000   0.001125    0.007070

# %% [markdown]
# Genes with at least one of these GO terms, sorted descending by number of GO terms

# %%
geneSelection = pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))].groupby("gene_id")["gene_id"].count())
geneSelection.columns = ["#go-terms"]
geneSelection = geneSelection.sort_values(by="#go-terms", ascending=False)
display(geneSelection)
# Out:
#                   #go-terms
# gene_id
# Solyc01g095040.2         12
# Solyc01g094800.2          5
# Solyc01g094700.2          2
# Solyc01g094760.2          2
# Solyc01g094790.2          2
# Solyc01g095080.2          2
# Solyc01g094720.2          1
# Solyc01g094830.2          1
# Solyc01g094880.2          1
# Solyc01g094930.2          1
# Solyc01g094960.2          1
# Solyc01g095050.2          1
# Solyc01g095070.2          1

# %%
pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))]).groupby(["gene_id","go_id"]).sum()[["go_term","go_cat"]]
# Out:
#                                                                        go_term  \
# gene_id          go_id
# Solyc01g094700.2 GO:0010143                         cutin biosynthetic process
#                  GO:0016311                                  dephosphorylation
# Solyc01g094720.2 GO:0098656                      anion transmembrane transport
# Solyc01g094760.2 GO:0006270                         DNA replication initiation
#                  GO:0009744                                response to sucrose
# Solyc01g094790.2 GO:0006535          cysteine biosynthetic process from serine
#                  GO:0019499                          cyanide metabolic process
# Solyc01g094800.2 GO:0010199  organ boundary specification between lateral o...
#                  GO:0040029          regulation of gene expression, epigenetic
#                  GO:0043044                 ATP-dependent chromatin remodeling
#                  GO:1900036   positive regulation of cellular response to heat
#                  GO:1903798  regulation of production of miRNAs involved in...
# Solyc01g094830.2 GO:0048544                              recognition of pollen
# Solyc01g094880.2 GO:0042147            retrograde transport, endosome to Golgi
# Solyc01g094930.2 GO:0071586                        CAAX-box protein processing
# Solyc01g094960.2 GO:0010468                      regulation of gene expression
# Solyc01g095040.2 GO:0000226              microtubule cytoskeleton organization
#                  GO:0008360                           regulation of cell shape
#                  GO:0009965                                 leaf morphogenesis
#                  GO:0010091                                 trichome branching
#                  GO:0010482              regulation of epidermal cell division
#                  GO:0031129                      inductive cell-cell signaling
#                  GO:0034063                            stress granule assembly
#                  GO:0042814                              monopolar cell growth
#                  GO:0045604       regulation of epidermal cell differentiation
#                  GO:0048444                         floral organ morphogenesis
#                  GO:0048530                                fruit morphogenesis
#                  GO:2000039               regulation of trichome morphogenesis
# Solyc01g095050.2 GO:0035308   negative regulation of protein dephosphorylation
# Solyc01g095070.2 GO:0046916          cellular transition metal ion homeostasis
# Solyc01g095080.2 GO:0009693                      ethylene biosynthetic process
#                  GO:0009835                                     fruit ripening
#
#                                          go_cat
# gene_id          go_id
# Solyc01g094700.2 GO:0010143  biological_process
#                  GO:0016311  biological_process
# Solyc01g094720.2 GO:0098656  biological_process
# Solyc01g094760.2 GO:0006270  biological_process
#                  GO:0009744  biological_process
# Solyc01g094790.2 GO:0006535  biological_process
#                  GO:0019499  biological_process
# Solyc01g094800.2 GO:0010199  biological_process
#                  GO:0040029  biological_process
#                  GO:0043044  biological_process
#                  GO:1900036  biological_process
#                  GO:1903798  biological_process
# Solyc01g094830.2 GO:0048544  biological_process
# Solyc01g094880.2 GO:0042147  biological_process
# Solyc01g094930.2 GO:0071586  biological_process
# Solyc01g094960.2 GO:0010468  biological_process
# Solyc01g095040.2 GO:0000226  biological_process
#                  GO:0008360  biological_process
#                  GO:0009965  biological_process
#                  GO:0010091  biological_process
#                  GO:0010482  biological_process
#                  GO:0031129  biological_process
#                  GO:0034063  biological_process
#                  GO:0042814  biological_process
#                  GO:0045604  biological_process
#                  GO:0048444  biological_process
#                  GO:0048530  biological_process
#                  GO:2000039  biological_process
# Solyc01g095050.2 GO:0035308  biological_process
# Solyc01g095070.2 GO:0046916  biological_process
# Solyc01g095080.2 GO:0009693  biological_process
#                  GO:0009835  biological_process
