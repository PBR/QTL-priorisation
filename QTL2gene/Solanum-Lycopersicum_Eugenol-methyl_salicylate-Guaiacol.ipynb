# %% [markdown]
# **Implementation algorithm**
#
# Prioritization of candidate genes in QTL regions based on associations between traits and biological processes.
# Bargsten JW, Nap JP, Sanchez-Perez GF, van Dijk AD.
# BMC Plant Biol. 2014 Dec 10;14:330. doi: 10.1186/s12870-014-0330-3.

# %%
import qtl2gene
import pandas as pd
search = qtl2gene.SEARCH(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl:8890/sparql")

# %% [markdown]
# ## Eugenol, methyl salicylate, Guaiacol
#
# GO-terms: GO:0042855,  GO:0042856,  GO:0042854,  GO:0080031, GO:0052689
#
# QTL from: Chromosome 9 : 69082273 - 69353332
#
# Candidate: ???

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
interval = search.make_interval(
    "http://localhost:8890/genome/Solanum_lycopersicum/chromosome/9", 
    69082273,
    69353332)

#genes for interval
genes = search.interval_genes(interval)
#goterms for genes
goterms = search.genes_goterms(genes["gene_id"].unique())
#compute the numbers 
gonumbers = search.get_go_numbers(goterms, genes)

# %% [markdown]
# Number of genes found in QTL

# %%
len(genes)
#pd.DataFrame(goterms.groupby(["go_id","go_cat","go_term"])["gene_id"].count())
# Out:
# 20

# %% [markdown]
# GO terms with boundary on adjusted p-value

# %%
p_boundary = 0.1
selection = gonumbers[gonumbers["p_adjusted"]<p_boundary]
pd.DataFrame(selection)[["p_less", "p_greater", "p_adjusted"]]
# Out:
#               p_less     p_greater    p_adjusted
# go_id
# GO:0009611  1.000000  3.872105e-35  1.161631e-34
# GO:0009693  0.999988  5.315838e-03  6.493484e-03
# GO:0009835  0.999982  6.493484e-03  6.493484e-03

# %% [markdown]
# Genes with at least one of these GO terms, sorted descending by number of GO terms

# %%
geneSelection = pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))].groupby("gene_id")["gene_id"].count())
geneSelection.columns = ["#go-terms"]
geneSelection = geneSelection.sort_values(by="#go-terms", ascending=False)
display(geneSelection)
# Out:
#                   #go-terms
# gene_id
# Solyc09g089580.2          2
# Solyc09g083430.1          1
# Solyc09g083440.2          1
# Solyc09g084440.2          1
# Solyc09g084450.2          1
# Solyc09g084460.2          1
# Solyc09g084470.2          1
# Solyc09g084480.2          1
# Solyc09g084490.2          1
# Solyc09g089490.2          1
# Solyc09g089500.2          1
# Solyc09g089510.2          1
# Solyc09g089520.2          1
# Solyc09g089530.2          1
# Solyc09g089540.2          1

# %%
pd.DataFrame(goterms[goterms["go_id"].isin(list(selection.index))]).groupby(["gene_id","go_id"]).sum()[["go_term","go_cat"]]
# Out:
#                                                    go_term              go_cat
# gene_id          go_id
# Solyc09g083430.1 GO:0009611           response to wounding  biological_process
# Solyc09g083440.2 GO:0009611           response to wounding  biological_process
# Solyc09g084440.2 GO:0009611           response to wounding  biological_process
# Solyc09g084450.2 GO:0009611           response to wounding  biological_process
# Solyc09g084460.2 GO:0009611           response to wounding  biological_process
# Solyc09g084470.2 GO:0009611           response to wounding  biological_process
# Solyc09g084480.2 GO:0009611           response to wounding  biological_process
# Solyc09g084490.2 GO:0009611           response to wounding  biological_process
# Solyc09g089490.2 GO:0009611           response to wounding  biological_process
# Solyc09g089500.2 GO:0009611           response to wounding  biological_process
# Solyc09g089510.2 GO:0009611           response to wounding  biological_process
# Solyc09g089520.2 GO:0009611           response to wounding  biological_process
# Solyc09g089530.2 GO:0009611           response to wounding  biological_process
# Solyc09g089540.2 GO:0009611           response to wounding  biological_process
# Solyc09g089580.2 GO:0009693  ethylene biosynthetic process  biological_process
#                  GO:0009835                 fruit ripening  biological_process
